# %%
import os
import analysis
from bmtool import bmplot
# %matplotlib inline

config_file = os.path.join('..', 'Model', 'config.json')

# %%
kwargs = {'sources': 'cortex', 'targets': 'cortex', 'sids': 'assembly_id', 'tids': 'assembly_id'}
bmplot.convergence_connection_matrix(config=config_file, include_gap=False, no_prepend_pop=True, **kwargs)

# %%
kwargs = {'sources': 'cortex', 'targets': 'cortex', 'sids': 'pop_name', 'tids': 'pop_name'}

# %%
bmplot.convergence_connection_matrix(config=config_file, include_gap=False, **kwargs)
# bmplot.convergence_connection_matrix(config=config_file, method='std', include_gap=False, **kwargs)
# bmplot.connection_matrix(config=config_file, synaptic_info="1", **kwargs)

# %%
bmplot.convergence_connection_matrix(config=config_file, include_gap=True, **kwargs)

# %%
# bmplot.connection_matrix(config=config_file, synaptic_info="1", **{**kwargs, 'sources': 'shell'})
bmplot.convergence_connection_matrix(config=config_file, **{**kwargs, 'sources': 'shell'})

# %%
# bmplot.divergence_connection_matrix(config=config_file, **kwargs)

# %%
# bmplot.probability_connection_matrix(config=config_file, bins=10, **kwargs)
