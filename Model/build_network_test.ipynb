# %%
import numpy as np
import os
from functools import partial
from copy import deepcopy
from bmtk.builder import NetworkBuilder
from bmtk.utils.sim_setup import build_env_bionet
import synapses
import connectors
from connectors import (
    num_prop, spherical_dist, cylindrical_dist_z, GaussianDropoff,
    pr_2_rho, rho_2_pr, ReciprocalConnector, UnidirectionConnector,
    OneToOneSequentialConnector, CorrelatedGapJunction,
    syn_dist_delay_feng_section_PN, syn_section_PN,
    syn_dist_delay_feng, syn_uniform_delay_section
)
from build_input import assign_assembly

# %%
randseed = 1234
rng = np.random.default_rng(randseed)
connectors.rng = rng

network_dir = 'network'
t_sim = 31000.0  # ms
dt = 0.1  # ms

# Total number of cells
num_cells = 1000  # 10000

# Network size and dimensions (um)
column_width, column_height = 600., 500.
x_start, x_end = - column_width / 2, column_width / 2
y_start, y_end = - column_width / 2, column_width / 2
z_start, z_end = - column_height / 2, column_height / 2
z_5A = 0.  # boundary between 5A and 5B

# Distance constraint for all cells
min_conn_dist = 20.0  # um. PN soma diameter
max_conn_dist = 300.0  # or np.inf
# Distance range for total probability in estimation of Gaussian drop function
# ptotal_dist_range = (0., 150.)

# PN assemblies. Cells in the same assembly have more connections
n_assemblies = 3  # number of PN assemblies
prob_ratio = 2  # ratio of connection probability within vs. between assemblies

# When enabled, a shell of virtual cells will be created around the core cells.
edge_effects = True


##############################################################################
############################## Cell Proportions ##############################

# Number of cells in each population.
# Following 80/20 E/I equal on CP-CS and 60% FSI to 40% LTS for Interneurons
# Densities by cell proportion unless otherwise specified:
# CP: 40%  CS: 40%  FSI: 12%  LTS: 8%
# Corticopontine, Corticostriatal, Fast Spiking Interneuron, Low Threshold Spiking
num_CP, num_CS, num_FSI, num_LTS = num_prop([40, 40, 12, 8], num_cells)

# Amount of cells per layer
# CP cells are basically only in layer 5B and nowhere else.
numCP_5A, numCP_5B = num_prop([5, 95], num_CP)
# CS cells span top of 5B to middle of 2/3
numCS_5A, numCS_5B = num_prop([95, 5], num_CS)
# Even distribution of FSI cells between Layers 5A and 5B
numFSI_5A, numFSI_5B = num_prop([1, 1], num_FSI)
# Even distribution of LTS cells between Layers 5A and 5B
numLTS_5A, numLTS_5B = num_prop([1, 1], num_LTS)

# Layer order from top to bottom is 5A, 5B
# Layer 5A (250 um thick) z is 0 to 250
# Layer 5B (250 um thick) z is -250 to 0
num_cells_5A = numCP_5A + numCS_5A + numFSI_5A + numLTS_5A
num_cells_5B = numCP_5B + numCS_5B + numFSI_5B + numLTS_5B

# Scaling factor of connection probabilities for PN assemblies
num_PN = num_CP + num_CS
# proportion of presynapstic cells in an assembly
assy_prop = (num_PN / n_assemblies - 1) / (num_PN - 1)
# Scale connection probability according to assembly
# If n_assemblies is 1, all PNs belong to the same assembly. Scaling factor is 1.
p_diff_scale = 1 / (assy_prop * (prob_ratio - 1) + 1)  # between assemblies
p_same_scale = p_diff_scale * prob_ratio  # within the same assembly

# %%
# Generate random cell positions
# Use poisson-disc sampling to generate positions with minimum distance limit.
use_poiss_disc = False

# Get positions for cells in the core
def samples_in_core(samples):
    core_idx = (samples[:, 0] >= x_start) & (samples[:, 0] <= x_end) & \
        (samples[:, 1] >= y_start) & (samples[:, 1] <= y_end) & \
        (samples[:, 2] >= z_start) & (samples[:, 2] <= z_end)
    pos_list_5 = samples[core_idx]  # layer 5 volume
    idx_5A = pos_list_5[:, 2] >= z_5A  # index in 5A, others in 5B
    return core_idx, pos_list_5[idx_5A], pos_list_5[~idx_5A]

# Generate samples in cube with side_length
side_length = max(column_width, column_height)
if edge_effects:
    side_length += 2 * max_conn_dist  # Extend by 2 * max_conn_dist

    # Compute the outer shell range. Extend the edge by max_conn_dist.
    shell_x_start, shell_y_start, shell_z_start = \
        np.array((x_start, y_start, z_start)) - max_conn_dist
    shell_x_end, shell_y_end, shell_z_end = \
        np.array((x_end, y_end, z_end)) + max_conn_dist

    # Compute the core and shell volume
    core_volume_5A = (x_end - x_start) * (y_end - y_start) * (z_end - z_5A)
    core_volume_5B = (x_end - x_start) * (y_end - y_start) * (z_5A - z_start)
    shell_volume_5A = (shell_x_end - shell_x_start) * \
        (shell_y_end - shell_y_start) * (shell_z_end - z_5A) - core_volume_5A
    shell_volume_5B = (shell_x_end - shell_x_start) * \
        (shell_y_end - shell_y_start) * (z_5A - shell_z_start) - core_volume_5B

    # Determine the number of shell cells with the same density
    virt_num_cells_5A = int(round(num_cells_5A *
                                  shell_volume_5A / core_volume_5A))
    virt_num_cells_5B = int(round(num_cells_5B *
                                  shell_volume_5B / core_volume_5B))

    # Get positions for cells in the shell
    def samples_in_shell(samples):
        shell_idx = (samples[:, 0] >= shell_x_start) &\
            (samples[:, 0] <= shell_x_end) & \
            (samples[:, 1] >= shell_y_start) & \
            (samples[:, 1] <= shell_y_end) & \
            (samples[:, 2] >= shell_z_start) &\
            (samples[:, 2] <= shell_z_end)
        pos_list_5 = samples[shell_idx]
        idx_5A = pos_list_5[:, 2] >= z_5A  # index in 5A, others in 5B
        return pos_list_5[idx_5A], pos_list_5[~idx_5A]

# Generate samples in cube [0, 1]^3, then scale it to side_length and center it
def scale_cube(samples):
    return side_length * (samples - 0.5)


if use_poiss_disc:
    from scipy.stats import qmc  # qmc.PoissonDisk new in scipy 1.10.0

    ncand = 30  # number of candidates (related to density of points)
    radius = min_conn_dist / side_length
    engine = qmc.PoissonDisk(d=3, radius=radius, ncandidates=ncand, seed=rng)
    samples = scale_cube(engine.fill_space())

    core_idx, pos_list_5A, pos_list_5B = samples_in_core(samples)
    print("Number of positions in 5A, 5B: (%d, %d)"
          % (len(pos_list_5A), len(pos_list_5B)))
    print("Number of cells in 5A, 5B: (%d, %d)"
          % (num_cells_5A, num_cells_5B))
    if len(pos_list_5A) < num_cells_5A or len(pos_list_5B) < num_cells_5B:
        raise ValueError("There are not enough position samples generated.")
    if edge_effects:
        shell_pos_list_5A, shell_pos_list_5B = \
            samples_in_shell(samples[~core_idx])
        print("Number of positions in 5A, 5B: (%d, %d)"
              % (len(shell_pos_list_5A), len(shell_pos_list_5B)))
        print("Number of cells in 5A, 5B: (%d, %d)"
              % (virt_num_cells_5A, virt_num_cells_5B))
        if len(shell_pos_list_5A) < virt_num_cells_5A or \
                len(shell_pos_list_5B) < virt_num_cells_5B:
            raise ValueError("There are not enough position samples "
                             "generated in shell.")
else:
    cell_dens = num_cells / (column_width * column_width * column_height)
    num_pos = int(cell_dens * side_length ** 3)
    samples = scale_cube(rng.random((num_pos, 3)))
    num_pos = int(0.1 * num_pos)
    while True:
        core_idx, pos_list_5A, pos_list_5B = samples_in_core(samples)
        add_samples = len(pos_list_5A) < num_cells_5A \
            or len(pos_list_5B) < num_cells_5B
        if edge_effects:
            shell_pos_list_5A, shell_pos_list_5B = \
                samples_in_shell(samples[~core_idx])
            add_samples = add_samples \
                or len(shell_pos_list_5A) < virt_num_cells_5A \
                or len(shell_pos_list_5B) < virt_num_cells_5B
        if add_samples:
            new_samples = scale_cube(rng.random((num_pos, 3)))
            samples = np.concatenate((samples, new_samples), axis=0)
        else:
            break

# Draw desired number of samples from the position list
pos_list_5A = rng.choice(pos_list_5A, num_cells_5A, replace=False)
pos_list_5B = rng.choice(pos_list_5B, num_cells_5B, replace=False)

if edge_effects:
    shell_pos_list_5A = rng.choice(shell_pos_list_5A,
                                   virt_num_cells_5A, replace=False)
    shell_pos_list_5B = rng.choice(shell_pos_list_5B,
                                   virt_num_cells_5B, replace=False)

    # Keep only the PN cells in the lateral shell around the core
    def shell_PN_5A(pos_list):
        return pos_list[pos_list[:, 2] <= z_end]

    def shell_PN_5B(pos_list):
        return pos_list[pos_list[:, 2] >= z_start]

    virt_numPN_5A, virt_numITN_5A = num_prop(
        [numCP_5A + numCS_5A, numFSI_5A + numLTS_5A], virt_num_cells_5A)
    virt_numPN_5B, virt_numITN_5B = num_prop(
        [numCP_5B + numCS_5B, numFSI_5B + numLTS_5B], virt_num_cells_5B)

    PN_list_5A = shell_PN_5A(shell_pos_list_5A[:virt_numPN_5A])
    ITN_list_5A = shell_pos_list_5A[virt_numPN_5A:]
    shell_pos_list_5A = np.concatenate((PN_list_5A, ITN_list_5A))
    PN_list_5B = shell_PN_5B(shell_pos_list_5B[:virt_numPN_5B])
    ITN_list_5B = shell_pos_list_5B[virt_numPN_5B:]
    shell_pos_list_5B = np.concatenate((PN_list_5B, ITN_list_5B))

    virt_numCP_5A, virt_numCS_5A = num_prop(
        [numCP_5A, numCS_5A], len(PN_list_5A))
    virt_numFSI_5A, virt_numLTS_5A = num_prop(
        [numFSI_5A, numLTS_5A], virt_numITN_5A)
    virt_numCP_5B, virt_numCS_5B = num_prop(
        [numCP_5B, numCS_5B], len(PN_list_5B))
    virt_numFSI_5B, virt_numLTS_5B = num_prop(
        [numFSI_5B, numLTS_5B], virt_numITN_5B)

# TODO: generate random orientations

# %%
# Generate assemblies for PNs. Divide evenly in each subtype of PN.
num_PN = np.cumsum([numCP_5A, numCS_5A, numCP_5B, numCS_5B])
# Assign an assembly id to each cell.
assy_ids = np.empty(num_PN[-1], dtype=int)
for i, idx in enumerate(assign_assembly(num_PN[-1], n_assemblies, rng=rng)):
    assy_ids[idx] = i
assy_ids = np.split(assy_ids, num_PN[:-1])

if edge_effects:
    virt_numPN = np.cumsum([virt_numCP_5A, virt_numCS_5A, virt_numCP_5B, virt_numCS_5B])
    virt_assy_ids = np.empty(virt_numPN[-1], dtype=int)
    for i, idx in enumerate(assign_assembly(virt_numPN[-1], n_assemblies, rng=rng)):
        virt_assy_ids[idx] = i
    virt_assy_ids = np.split(virt_assy_ids, virt_numPN[:-1])

# %%
##############################################################################
####################### Functions for Building Network #######################

# Dictionary to store NetworkBuilder objects referenced by name
networks = {}

def build_networks(network_definitions: list) -> dict:
    """
    `network_definitions` should be a list of dictionaries, e.g. [{}, {}, ...]
    Keys should include an arbitrary `network_name`, a positions_list (if any),
    and `cells`. `cells` should contain a list of dictionaries, and each
    dictionary should corrospond with any valid input for BMTK
    NetworkBuilder.add_nodes() method. A dictionary of BMTK NetworkBuilder
    objects will be returned, reference by individual network_name."""
    for net_def in network_definitions:
        network_name = net_def['network_name']
        if networks.get(network_name) is None:
            networks[network_name] = NetworkBuilder(network_name)
        pos_list = net_def.get('positions_list')

        # Add cells to the network
        num = 0
        for cell in net_def['cells']:
            num_cells = cell['N']
            extra_kwargs = {}
            if pos_list is not None:
                extra_kwargs['positions'] = pos_list[num:num + num_cells]
                num += num_cells

            cell = {k: v for k, v in cell.items() if v is not None}
            extra_kwargs = {k: v for k, v in extra_kwargs.items()
                            if v is not None}
            networks[network_name].add_nodes(**cell, **extra_kwargs)

    return networks


def build_edges(networks, edge_definitions, edge_params,
                edge_add_properties, syn):
    """
    Builds the edges for each network given a set of 'edge_definitions',
    examples shown later in the code
    """
    for edge in edge_definitions:
        network_name = edge['network']
        net = networks[network_name]
        # edge arguments
        print("Adding edge: " + edge['param'])
        edge_params_val = edge_params[edge['param']].copy()
        # get synapse template file
        dynamics_file = edge_params_val.get('dynamics_params')
        model_template = syn[dynamics_file]['level_of_detail']
        # get source and target nodes
        edge_src_trg = edge.get('edge')
        if edge_src_trg:
            edge_src_trg = edge_src_trg.copy()
            src_net = edge_src_trg.pop('source_network', network_name)
            trg_net = edge_src_trg.pop('target_network', network_name)
            source = networks[src_net].nodes(**edge_src_trg.get('source', {}))
            target = networks[trg_net].nodes(**edge_src_trg.get('target', {}))
            edge_params_val.update({'source': source, 'target': target})
        # use connector class
        connector_class = edge_params_val.pop('connector_class', None)
        if connector_class is not None:
            # create a connector object
            connector_params = edge_params_val.pop('connector_params', {})
            connector = connector_class(**connector_params)
            # keep object reference in the dictionary
            edge_params[edge['param']]['connector_object'] = connector
            if edge_src_trg:
                connector.setup_nodes(source=source, target=target)
            edge_params_val.update(connector.edge_params())
        conn = net.add_edges(model_template=model_template, **edge_params_val)

        edge_properties = edge.get('add_properties')
        if edge_properties:
            edge_properties_val = edge_add_properties[edge_properties].copy()
            if connector_class is not None:
                # pass connector object to the rule for edge properties
                edge_properties_val['rule'] = partial(
                    edge_properties_val['rule'], connector=connector)
            conn.add_properties(**edge_properties_val)


def get_connector(param):
    """Get connector object stored in edge_params"""
    edge_params_val = edge_params[param]
    if 'connector_object' in edge_params_val:
        return edge_params_val['connector_object']
    else:
        raise ValueError("No connector used in '%s'" % param)


def save_networks(networks, network_dir):
    """Build and save network"""
    # Remove the existing network_dir directory
    if os.path.isdir(network_dir):
        for f in os.listdir(network_dir):
            os.remove(os.path.join(network_dir, f))

    # Run through each network and save their nodes/edges
    for network_name, network in networks.items():
        print('Building ' + network_name)
        network.build()
        network.save_nodes(output_dir=network_dir)
        network.save_edges(output_dir=network_dir)

# %%
##############################################################################
############################ Network Definitions #############################

network_definitions = [
    {   # Start Layer 5A
        'network_name': 'cortex',
        'positions_list': pos_list_5A,
        'cells': [
            {   # CP
                'N': numCP_5A,
                'pop_name': 'CP',
                'assembly_id': assy_ids[0],
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:CP_Cell',
                'morphology': 'blank.swc'
            },
            {   # CS
                'N': numCS_5A,
                'pop_name': 'CS',
                'assembly_id': assy_ids[1],
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:CS_Cell',
                'morphology': 'blank.swc'
            },
            {   # FSI
                'N': numFSI_5A,
                'pop_name': 'FSI',
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:FSI_Cell',
                'morphology': 'blank.swc'
            },
            {   # LTS
                'N': numLTS_5A,
                'pop_name': 'LTS',
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:LTS_Cell',
                'morphology': 'blank.swc'
            }
        ]
    },  # End Layer 5A
    {   # Start Layer 5B
        'network_name': 'cortex',
        'positions_list': pos_list_5B,
        'cells': [
            {   # CP
                'N': numCP_5B,
                'pop_name': 'CP',
                'assembly_id': assy_ids[2],
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:CP_Cell',
                'morphology': 'blank.swc'
            },
            {   # CS
                'N': numCS_5B,
                'pop_name': 'CS',
                'assembly_id': assy_ids[3],
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:CS_Cell',
                'morphology': 'blank.swc'
            },
            {   # FSI
                'N': numFSI_5B,
                'pop_name': 'FSI',
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:FSI_Cell',
                'morphology': 'blank.swc'
            },
            {   # LTS
                'N': numLTS_5B,
                'pop_name': 'LTS',
                'rotation_angle_zaxis': None,
                'rotation_angle_yaxis': None,
                'model_type': 'biophysical',
                'model_template': 'hoc:LTS_Cell',
                'morphology': 'blank.swc'
            }
        ]
    },  # End Layer 5B
    {   # Extrinsic Thalamic Inputs
        'network_name': 'thalamus',
        'positions_list': None,
        'cells': [
            {   # Virtual Cells
                'N': num_CP + num_CS,
                'pop_name': 'thal',
                'potential': 'exc',
                'model_type': 'virtual'
            }
        ]
    },
    {   # Extrinsic Baseline Inputs
        'network_name': 'baseline',
        'positions_list': None,
        'cells': [
            {   # Virtual Cells
                'N': num_cells,
                'pop_name': 'base',
                'potential': 'exc',
                'model_type': 'virtual'
            }
        ]
    }
]

##############################################################################
################################ EDGE EFFECTS ################################

if edge_effects:
    # This network should contain all the same properties as the original
    # network, except the cell should be virtual. For connectivity, you should
    # name the cells the same as the original network because connection rules
    # defined later will require it
    shell_network = [
        {   # Start Layer 5A
            'network_name': 'shell',
            'positions_list': shell_pos_list_5A,
            'cells': [
                {   # CP
                    'N': virt_numCP_5A,
                    'pop_name': 'CP',
                    'assembly_id': virt_assy_ids[0],
                    'model_type': 'virtual'
                },
                {   # CS
                    'N': virt_numCS_5A,
                    'pop_name': 'CS',
                    'assembly_id': virt_assy_ids[1],
                    'model_type': 'virtual'
                },
                {   # FSI
                    'N': virt_numFSI_5A,
                    'pop_name': 'FSI',
                    'model_type': 'virtual'
                },
                {   # LTS
                    'N': virt_numLTS_5A,
                    'pop_name': 'LTS',
                    'model_type': 'virtual'
                }
            ]
        },  # End Layer 5A
        {   # Start Layer 5B
            'network_name': 'shell',
            'positions_list': shell_pos_list_5B,
            'cells': [
                {   # CP
                    'N': virt_numCP_5B,
                    'pop_name': 'CP',
                    'assembly_id': virt_assy_ids[2],
                    'model_type': 'virtual'
                },
                {   # CS
                    'N': virt_numCS_5B,
                    'pop_name': 'CS',
                    'assembly_id': virt_assy_ids[3],
                    'model_type': 'virtual'
                },
                {   # FSI
                    'N': virt_numFSI_5B,
                    'pop_name': 'FSI',
                    'model_type': 'virtual'
                },
                {   # LTS
                    'N': virt_numLTS_5B,
                    'pop_name': 'LTS',
                    'model_type': 'virtual'
                }
            ]
        }  # End Layer 5B
    ]

    # Add the shell to our network definitions
    network_definitions.extend(shell_network)

############################## END EDGE EFFECTS ##############################
##############################################################################

# Set assembly_id to -1 for populations that form no assembly
assembly_network = {'cortex', 'shell'}
for net_df in network_definitions:
    if net_df['network_name'] in assembly_network:
        for c in net_df['cells']:
            if 'assembly_id' not in c:
                c['assembly_id'] = -1

# Build and save our NetworkBuilder dictionary
networks = build_networks(network_definitions)

# %%
##########################################################################
#############################  BUILD EDGES  ##############################

# Whole reason for restructuring network building lies here, by separating out
# the source and target params from the remaining parameters in
# NetworkBuilder.add_edges() function we can reuse connectivity rules for the
# virtual shell or elsewhere
# [
#  {
#   'network': 'network_name',  # Name of the network to which edges are added
#   'edge': {
#       'source': {},  # dictionary of properties of desired population
#       'target': {},
#       'source_network': 'network_name1'  # network name for the population
#       'target_network': 'network_name2'  # if different from network_name
#       },  # source and target are required
#       # source_network and target_network are optional
#   'param': 'name_of_edge_parameters',  # to be coupled with when add_edges()
#   'add_properties': 'prop_name'  # name of edge_add_properties for additional
#       # connection properties, like delay
#   }
# ]

edge_definitions = [
    {   # CP -> CP Reciprocal
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CP'},
            'target': {'pop_name': 'CP'}
        },
        'param': 'CP2CP',
        'add_properties': 'syn_dist_delay_feng_section_PN'
    },
    {   # CS -> CS Reciprocal
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CS'},
            'target': {'pop_name': 'CS'}
        },
        'param': 'CS2CS',
        'add_properties': 'syn_dist_delay_feng_section_PN'
    },
    {   # CP -> CS Unidirectional
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CP'},
            'target': {'pop_name': 'CS'}
        },
        'param': 'CP2CS',
        'add_properties': 'syn_dist_delay_feng_section_PN'
    },
    {   # CS -> CP Unidirectional
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CS'},
            'target': {'pop_name': 'CP'}
        },
        'param': 'CS2CP',
        'add_properties': 'syn_dist_delay_feng_section_PN'
    },
    {   # FSI -> FSI Reciprocal
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'FSI'},
            'target': {'pop_name': 'FSI'}
        },
        'param': 'FSI2FSI',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # LTS -> LTS Unidirectional
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'LTS'},
            'target': {'pop_name': 'LTS'}
        },
        'param': 'LTS2LTS',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # FSI -> LTS forward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'FSI'},
            'target': {'pop_name': 'LTS'}
        },
        'param': 'FSI2LTS',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # FSI <- LTS backward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'LTS'},
            'target': {'pop_name': 'FSI'}
        },
        'param': 'LTS2FSI',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CP -> FSI forward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CP'},
            'target': {'pop_name': 'FSI'}
        },
        'param': 'CP2FSI',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CP <- FSI backward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'FSI'},
            'target': {'pop_name': 'CP'}
        },
        'param': 'FSI2CP',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CS -> FSI forward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CS'},
            'target': {'pop_name': 'FSI'}
        },
        'param': 'CS2FSI',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CS <- FSI backward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'FSI'},
            'target': {'pop_name': 'CS'}
        },
        'param': 'FSI2CS',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CP -> LTS forward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CP'},
            'target': {'pop_name': 'LTS'}
        },
        'param': 'CP2LTS',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CP <- LTS backward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'LTS'},
            'target': {'pop_name': 'CP'}
        },
        'param': 'LTS2CP',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CS -> LTS forward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'CS'},
            'target': {'pop_name': 'LTS'}
        },
        'param': 'CS2LTS',
        'add_properties': 'syn_dist_delay_feng_default'
    },
    {   # CS <- LTS backward
        'network': 'cortex',
        'edge': {
            'source': {'pop_name': 'LTS'},
            'target': {'pop_name': 'CS'}
        },
        'param': 'LTS2CS',
        'add_properties': 'syn_dist_delay_feng_default'
    },
        ################### THALAMIC INPUT ###################
    {   # Thalamus Excitation to CP
        'network': 'cortex',
        'edge': {
            'source_network': 'thalamus',
            'source': {},
            'target': {'pop_name': 'CP'}
        },
        'param': 'Thal2CP'
    },
    {   # Thalamus Excitation to CS
        'network': 'cortex',
        'edge': {
            'source_network': 'thalamus',
            'source': {},
            'target': {'pop_name': 'CS'}
        },
        'param': 'Thal2CS'
    },
        ################### Baseline INPUT ###################
    {   # Excitation to CP
        'network': 'cortex',
        'edge': {
            'source_network': 'baseline',
            'source': {},
            'target': {'pop_name': 'CP'}
        },
        'param': 'Base2CP'
    },
    {   # Excitation to CS
        'network': 'cortex',
        'edge': {
            'source_network': 'baseline',
            'source': {},
            'target': {'pop_name': 'CS'}
        },
        'param': 'Base2CS'
    },
    {   # Excitation to FSI
        'network': 'cortex',
        'edge': {
            'source_network': 'baseline',
            'source': {},
            'target': {'pop_name': 'FSI'}
        },
        'param': 'Base2FSI'
    },
    {   # Excitation to LTS
        'network': 'cortex',
        'edge': {
            'source_network': 'baseline',
            'source': {},
            'target': {'pop_name': 'LTS'}
        },
        'param': 'Base2LTS'
    }
]

# %%
##########################  CONSTRUCT ASSEMBLIES  ###########################

# Update edge definitions to create specifics of all possible edges between assemblies
assy_pop_name = {'CP', 'CS'}  # pop_name of populations that form assemblies
edge_definitions_new = []
for edge in edge_definitions:
    src_trg = edge.get('edge', {})
    src_trg = [src_trg.get(p, {}).get('pop_name', [None]) for p in ('source', 'target')]
    # ensure pop_name is in list format
    src_trg = [[p] if isinstance(p, str) else list(p) for p in src_trg]
    if set(src_trg[0] + src_trg[1]).issubset(assy_pop_name):
        edge['edge']['source']['pop_name'] = src_trg[0]
        edge['edge']['target']['pop_name'] = src_trg[1]
        edges = []
        for i in range(n_assemblies):
            for j in range(n_assemblies):
                subedge = deepcopy(edge)
                subedge['assy_type'] = subedge['param']  # original `param` name
                # add assembly_id to population filter conditions
                subedge['edge']['source']['assembly_id'] = i
                subedge['edge']['target']['assembly_id'] = j
                # new `param` name with assembly id labels
                subedge['param'] += '_%d_%d' % (i, j) 
                edges.append(subedge)
        edge_definitions_new.extend(edges)
    else:
        edge_definitions_new.append(edge)
edge_definitions = edge_definitions_new

# %%
# Specify overall connection probability regardless of assemblies
conn_prob = {
    'CP2CP': GaussianDropoff(stdev=127.0, min_dist=0., max_dist=max_conn_dist,
        ptotal=0.0866, ptotal_dist_range=(0., 100.), dist_type='cylindrical'),
    'CS2CS': GaussianDropoff(stdev=127.0, min_dist=0., max_dist=max_conn_dist,
        ptotal=0.077, ptotal_dist_range=(0., 100.), dist_type='cylindrical'),
    'CP2CS': GaussianDropoff(stdev=127.0, min_dist=0., max_dist=max_conn_dist,
        ptotal=0.01, ptotal_dist_range=(0., 100.), dist_type='cylindrical'),
    'CS2CP': GaussianDropoff(stdev=127.0, min_dist=0., max_dist=max_conn_dist,
        ptotal=0.112, ptotal_dist_range=(0., 100.), dist_type='cylindrical')
}

# Create connection probabilities using scaled distance dependent Gaussian rules
# for connections within the same assembly or between different assemblies.
keys = ['mean', 'stdev', 'min_dist', 'max_dist', 'dist_type']
assy_conn_prob = {}
for conn, gauss in conn_prob.items():
    pmax = gauss.pmax
    kwargs = {key: getattr(gauss, key) for key in keys}
    assy_conn_prob[conn] = {
        True: GaussianDropoff(pmax=p_same_scale * pmax, **kwargs),
        False: GaussianDropoff(pmax=p_diff_scale * pmax, **kwargs)
    }

# Specify common edge parameters (see format of `edge_params` later) for
# connections between populations that form assemblies.
# Scaled connection probability will be added according to assemblies.   
all_assy_edge_params = {
    'CP2CP': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': None,  # to be substituted
            'p0_arg': cylindrical_dist_z,
            'pr': 0.042, 'estimate_rho': True,
            'dist_range_forward': (0., 100.)
        },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,
        'afferent_section_pos': 0.4,
        'dynamics_params': 'CP2CP.json'
    },
    'CS2CS': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': None,
            'p0_arg': cylindrical_dist_z,
            'pr': 0.015, 'estimate_rho': True,
            'dist_range_forward': (0., 100.)
        },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,
        'afferent_section_pos': 0.4,
        'dynamics_params': 'CS2CS.json'
    },
    'CP2CS': {
        'connector_class': UnidirectionConnector,
        'connector_params': {
            'p': None,
            'p_arg': cylindrical_dist_z,
        },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,
        'afferent_section_pos': 0.4,
        'dynamics_params': 'CP2CS.json'
    },
    'CS2CP': {
        'connector_class': UnidirectionConnector,
        'connector_params': {
            'p': None,
            'p_arg': cylindrical_dist_z,
        },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,
        'afferent_section_pos': 0.4,
        'dynamics_params': 'CS2CP.json'
    }
}

# %%
# Create edge parameters for all possible edges between assemblies using common
# parameters specified in `all_assy_edge_params`.
# Add scaled connection probabilities to connector classes. 
assy_edge_params = {}
for edge in edge_definitions:
    if 'assy_type' not in edge:  # identify edges between assemblies
        continue
    # get edge parameters
    assy_type, assy_conn = edge['assy_type'], edge['param']
    edge_params_val = deepcopy(all_assy_edge_params[assy_type])
    connector_params = edge_params_val['connector_params']
    # get source and target populations
    src, trg = edge['edge']['source'], edge['edge']['target']
    src_assy, trg_assy = src['assembly_id'], trg['assembly_id']
    # get scaled connection probability
    prob = assy_conn_prob[assy_type][src_assy == trg_assy]
    # update connector class and connector parameters
    connector_class = edge_params_val['connector_class']
    if connector_class is UnidirectionConnector:
        connector_params['p'] = prob
    elif connector_class is ReciprocalConnector:
        connector_params['p0'] = prob
        if src['pop_name'] == trg['pop_name']:
            connector_params['symmetric_p1'] = True
            connector_params['symmetric_p1_arg'] = True
            conj_assy_conn = assy_type + '_%d_%d' % (trg_assy, src_assy)
            if conj_assy_conn in assy_edge_params:
                edge_params_val['connector_class'] = get_connector
                edge_params_val['connector_params'] = {'param': conj_assy_conn}
    elif connector_class is get_connector:
        conj_assy_type = connector_params['param']
        conj_assy_conn = conj_assy_type + '_%d_%d' % (trg_assy, src_assy)
        if conj_assy_conn not in assy_edge_params:
            raise ValueError("When using `ReciprocalConnector` and `get_connector`"
                " with assemblies, the two directional connections between two "
                "distinct populations should occur in the same order in both "
                "dictionaries of `edge_definitions` and `edge_params`.")
        assy_edge_params[conj_assy_conn]['connector_params']['p1'] = prob
        connector_params['param'] = conj_assy_conn
    else:
        raise TypeError("Connector type `%s` not supported." % 
            getattr(connector_class, '__name__', str(connector_class)))
    assy_edge_params[assy_conn] = edge_params_val

# %%
#############################  EDGE PARAMETERS  ##############################

# edge_params should contain additional parameters to be added to add_edges().
# The following parameters for random synapse placement are not necessary in
# edge_params if afferent_section_id and afferent_section_pos are specified.
# distance_range: place synapse within distance range [dmin, dmax] from soma.
# target_sections: place synapse within the given sections in a list.
# afferent_section_id must be specified here even though it will be overwritten
# by add_properties(), since there could be potential error due to the dtype
# being forced to be converted to float if values are not specified in the
# corresponding column in the edge csv file.
edge_params = {
    **assy_edge_params,
    'FSI2FSI': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': GaussianDropoff(
                stdev=126.77, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.103, ptotal_dist_range=(min_conn_dist, 200.),
                dist_type='spherical'),
            'p0_arg': spherical_dist,
            'pr': 0.04,
            'estimate_rho': True,
            'dist_range_forward': (min_conn_dist, 100.)
            # 'rho': pr_2_rho(0.103, 0.103, 0.04)  # use fixed rho instead
            },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 0,  # soma
        'afferent_section_pos': 0.5,
        'dynamics_params': 'FSI2FSI.json'
    },
    'LTS2LTS': {
        'connector_class': UnidirectionConnector,
        'connector_params': {
            'p': GaussianDropoff(
                stdev=126.77, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.15, ptotal_dist_range=(min_conn_dist, 50.),
                dist_type='spherical'),
            'p_arg': spherical_dist
            },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 0,  # soma
        'afferent_section_pos': 0.5,
        'dynamics_params': 'LTS2LTS.json'
    },
    'FSI2LTS': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': GaussianDropoff(
                stdev=126.77, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.34, ptotal_dist_range=(min_conn_dist, 50.),
                dist_type='spherical'),
            'p0_arg': spherical_dist,
            'p1': GaussianDropoff(
                stdev=126.77, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.53, ptotal_dist_range=(min_conn_dist, 50.),
                dist_type='spherical'),  # 53% unidirectional
            'p1_arg': spherical_dist,
            'pr': 0.22,
            'estimate_rho': True,
            'dist_range_forward': (min_conn_dist, 50.)
            },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 0,  # soma
        'afferent_section_pos': 0.5,
        'dynamics_params': 'FSI2LTS.json'
    },
    'LTS2FSI': {
        'connector_class': get_connector,
        'connector_params': {'param': 'FSI2LTS'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 0,  # soma
        'afferent_section_pos': 0.5,
        'dynamics_params': 'LTS2FSI.json'
    },
    'CP2FSI': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': GaussianDropoff(
                stdev=99.84, min_dist=0., max_dist=max_conn_dist,
                ptotal=0.32, ptotal_dist_range=(0., 100.),
                dist_type='cylindrical'),
            'p0_arg': cylindrical_dist_z,
            'p1': GaussianDropoff(
                stdev=96.60, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.48, ptotal_dist_range=(min_conn_dist, 100.),
                dist_type='spherical'),
            'p1_arg': spherical_dist,
            'pr': 0.26,
            'estimate_rho': True,
            'dist_range_backward': (min_conn_dist, 100.)
            },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,  # dend
        'afferent_section_pos': 0.5,
        'dynamics_params': 'CP2FSI.json'
    },
    'FSI2CP': {
        'connector_class': get_connector,
        'connector_params': {'param': 'CP2FSI'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 0,  # soma
        'afferent_section_pos': 0.5,
        'dynamics_params': 'FSI2CP.json'
    },
    'CS2FSI': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': GaussianDropoff(
                stdev=99.84, min_dist=0., max_dist=max_conn_dist,
                ptotal=0.22, ptotal_dist_range=(0., 100.),
                dist_type='cylindrical'),
            'p0_arg': cylindrical_dist_z,
            'p1': GaussianDropoff(
                stdev=96.60, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.36, ptotal_dist_range=(min_conn_dist, 100.),
                dist_type='spherical'),
            'p1_arg': spherical_dist,
            'pr': 0.17,
            'estimate_rho': True,
            'dist_range_backward': (min_conn_dist, 100.)
            },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,  # dend
        'afferent_section_pos': 0.5,
        'dynamics_params': 'CS2FSI.json'
    },
    'FSI2CS': {
        'connector_class': get_connector,
        'connector_params': {'param': 'CS2FSI'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 0,  # soma
        'afferent_section_pos': 0.5,
        'dynamics_params': 'FSI2CS.json'
    },
    'CP2LTS': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': GaussianDropoff(
                stdev=99.84, min_dist=0., max_dist=max_conn_dist,
                ptotal=0.28, ptotal_dist_range=(0., 100.),
                dist_type='cylindrical'),
            'p0_arg': cylindrical_dist_z,
            'p1': GaussianDropoff(
                stdev=96.60, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.39, ptotal_dist_range=(min_conn_dist, 100.),
                dist_type='spherical'),
            'p1_arg': spherical_dist,
            'pr': 0.16,
            'estimate_rho': True,
            'dist_range_backward': (min_conn_dist, 100.)
            },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,  # dend
        'afferent_section_pos': 0.5,
        'dynamics_params': 'CP2LTS.json'
    },
    'LTS2CP': {
        'connector_class': get_connector,
        'connector_params': {'param': 'CP2LTS'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 2,
        'afferent_section_pos': 0.8,  # end of apic
        'dynamics_params': 'LTS2CP.json'
    },
    'CS2LTS': {
        'connector_class': ReciprocalConnector,
        'connector_params': {
            'p0': GaussianDropoff(
                stdev=99.84, min_dist=0., max_dist=max_conn_dist,
                ptotal=0.13, ptotal_dist_range=(0., 100.),
                dist_type='cylindrical'),
            'p0_arg': cylindrical_dist_z,
            'p1': GaussianDropoff(
                stdev=96.60, min_dist=min_conn_dist, max_dist=max_conn_dist,
                ptotal=0.086, ptotal_dist_range=(min_conn_dist, 100.),
                dist_type='spherical'),
            'p1_arg': spherical_dist,
            'pr': 0.057,
            'estimate_rho': True,
            'dist_range_backward': (min_conn_dist, 100.)
            },
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 1,  # dend
        'afferent_section_pos': 0.5,
        'dynamics_params': 'CS2LTS.json'
    },
    'LTS2CS': {
        'connector_class': get_connector,
        'connector_params': {'param': 'CS2LTS'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.8,
        'sigma_upper_bound': 3.,
        'afferent_section_id': 2,
        'afferent_section_pos': 0.8,  # end of apic
        'dynamics_params': 'LTS2CS.json'
    },
    'Thal2CP': {
        'connector_class': OneToOneSequentialConnector,
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.3,
        'sigma_upper_bound': 3.,
        'delay': 0.0,
        'afferent_section_id': 2,
        'afferent_section_pos': 0.8,  # end of apic
        'dynamics_params': 'Thal2CP.json'
    },
    'Thal2CS': {
        'connector_class': get_connector,
        'connector_params': {'param': 'Thal2CP'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.3,
        'sigma_upper_bound': 3.,
        'delay': 0.0,
        'afferent_section_id': 2,
        'afferent_section_pos': 0.8,  # end of apic
        'dynamics_params': 'Thal2CS.json'
    },
    'Base2CP': {
        'connector_class': OneToOneSequentialConnector,
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.3,
        'sigma_upper_bound': 3.,
        'delay': 0.0,
        'afferent_section_id': 2,
        'afferent_section_pos': 0.8,  # end of apic
        'dynamics_params': 'Thal2CP.json'
    },
    'Base2CS': {
        'connector_class': get_connector,
        'connector_params': {'param': 'Base2CP'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.3,
        'sigma_upper_bound': 3.,
        'delay': 0.0,
        'afferent_section_id': 2,
        'afferent_section_pos': 0.8,  # end of apic
        'dynamics_params': 'Thal2CS.json'
    },
    'Base2FSI': {
        'connector_class': get_connector,
        'connector_params': {'param': 'Base2CP'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.6,
        'sigma_upper_bound': 3.,
        'delay': 0.0,
        'afferent_section_id': 1,  # dend
        'afferent_section_pos': 0.5,
        'dynamics_params': 'Base2FSI.json'
    },
    'Base2LTS': {
        'connector_class': get_connector,
        'connector_params': {'param': 'Base2CP'},
        'weight_function': 'lognormal_weight',
        'syn_weight': 1.,
        'weight_sigma': 0.6,
        'sigma_upper_bound': 3.,
        'delay': 0.0,
        'afferent_section_id': 1,  # dend
        'afferent_section_pos': 0.5,
        'dynamics_params': 'Base2LTS.json'
    }
}  # edges referenced by name

# Will be called by conn.add_properties() for the associated connection
edge_add_properties = {
    'syn_dist_delay_feng_section_PN': {
        'names': ['delay', 'afferent_section_id', 'afferent_section_pos'],
        'rule': syn_dist_delay_feng_section_PN,
        'rule_params': {
            'p': 0.9, 'sec_id': (1, 2), 'sec_x': (0.4, 0.6), 'min_delay': 0.8
        },
        'dtypes': [float, np.uint16, float]
    },
    'syn_section_PN': {
        'names': ['afferent_section_id', 'afferent_section_pos'],
        'rule': syn_section_PN,
        'rule_params': {'p': 0.9, 'sec_id': (1, 2), 'sec_x': (0.4, 0.6)},
        'dtypes': [np.uint16, float]
    },
    'syn_dist_delay_feng_default': {
        'names': 'delay',
        'rule': syn_dist_delay_feng,
        'dtypes': float
    },
    'syn_uniform_delay_section': {
        'names': 'delay',
        'rule': syn_uniform_delay_section,
        'rule_params': {'low': 0.8, 'high': 1.2},
        'dtypes': float
    }
}

# %%
# Load synapse dictionaries
# See synapses.py - loads each json's in components/synaptic_models/synapses_STP
# into a dictionary so the properties can be referenced in the files,
# e.g., syn['file.json'].get('property')
syn_dir = 'components/synaptic_models/synapses_STP'
synapses.load(rng_obj=rng)  # rng not used during building
syn = synapses.syn_params_dicts(syn_dir=syn_dir)

# Build your edges into the networks
build_edges(networks, edge_definitions, edge_params, edge_add_properties, syn)
# Out:
# Adding edge: CP2CP_0_0
# Adding edge: CP2CP_0_1
# Adding edge: CP2CP_0_2
# Adding edge: CP2CP_1_0
# Adding edge: CP2CP_1_1
# Adding edge: CP2CP_1_2
# Adding edge: CP2CP_2_0
# Adding edge: CP2CP_2_1
# Adding edge: CP2CP_2_2
# Adding edge: CS2CS_0_0
# Adding edge: CS2CS_0_1
# Adding edge: CS2CS_0_2
# Adding edge: CS2CS_1_0
# Adding edge: CS2CS_1_1
# Adding edge: CS2CS_1_2
# Adding edge: CS2CS_2_0
# Adding edge: CS2CS_2_1
# Adding edge: CS2CS_2_2
# Adding edge: CP2CS_0_0
# Adding edge: CP2CS_0_1
# Adding edge: CP2CS_0_2
# Adding edge: CP2CS_1_0
# Adding edge: CP2CS_1_1
# Adding edge: CP2CS_1_2
# Adding edge: CP2CS_2_0
# Adding edge: CP2CS_2_1
# Adding edge: CP2CS_2_2
# Adding edge: CS2CP_0_0
# Adding edge: CS2CP_0_1
# Adding edge: CS2CP_0_2
# Adding edge: CS2CP_1_0
# Adding edge: CS2CP_1_1
# Adding edge: CS2CP_1_2
# Adding edge: CS2CP_2_0
# Adding edge: CS2CP_2_1
# Adding edge: CS2CP_2_2
# Adding edge: FSI2FSI
# Adding edge: LTS2LTS
# Adding edge: FSI2LTS
# Adding edge: LTS2FSI
# Adding edge: CP2FSI
# Adding edge: FSI2CP
# Adding edge: CS2FSI
# Adding edge: FSI2CS
# Adding edge: CP2LTS
# Adding edge: LTS2CP
# Adding edge: CS2LTS
# Adding edge: LTS2CS
# Adding edge: Thal2CP
# Adding edge: Thal2CS
# All target population partitions are filled.
# Adding edge: Base2CP
# Adding edge: Base2CS
# Adding edge: Base2FSI
# Adding edge: Base2LTS
# All target population partitions are filled.

# %%
##############################################################################
############################  EDGE EFFECTS EDGES  ############################

if edge_effects:
    # These rules are for edge effect edges. They should mimic the connections
    # created previously but using unidirectional connector.
    # Re-use the connector params set above.

    # Find core network edge types that need shell connections
    core_network_name = 'cortex'
    core_edge_def = []
    for edge in edge_definitions:
        network_name = edge['network']
        if network_name != core_network_name:
            continue
        is_core = True
        edge_src_trg = edge.get('edge')
        if edge_src_trg:
            for net_type in ('source_network', 'target_network'):
                net_name = edge_src_trg.get(net_type)
                if net_name is not None and net_name != core_network_name:
                    is_core = False
        if is_core:
            core_edge_def.append(edge)

    # Automatically set up network edges and parameters for shell network
    # Only connections from shell to core is needed, so UnidirectionConnector
    # is used, and parameters are extracted from connectors used in core edges.
    shell_network_name = 'shell'
    shell_edges = []
    shell_edge_params = {}
    for edge in core_edge_def:
        shell_edge = edge.copy()
        edge_src_trg = shell_edge.get('edge')
        if edge_src_trg:
            edge_src_trg['source_network'] = shell_network_name
        shell_edge['param'] = shell_network_name + shell_edge['param']
        shell_edges.append(shell_edge)

        edge_params_val = edge_params[edge['param']].copy()
        connector = edge_params_val.pop('connector_object', None)
        connector_class = edge_params_val.get('connector_class')
        if (connector_class is not None and
                connector_class is not UnidirectionConnector):
            replace = True
            var_list = ('p', 'p_arg', 'n_syn')
            if connector_class is ReciprocalConnector:
                var_map = ('p0', 'p0_arg', 'n_syn0')
            elif connector_class is get_connector:
                var_map = ('p1', 'p1_arg', 'n_syn1')
            else:
                replace = False
                print("Warning: Connector method not identified. "
                      "Use the same connector class for shell edges.")
            if replace:
                edge_params_val['connector_class'] = UnidirectionConnector
                connector_params = {
                    k: connector.vars[k0] for k, k0 in zip(var_list, var_map)
                    }
                connector_params['verbose'] = connector.verbose
                edge_params_val['connector_params'] = connector_params
        shell_edge_params[shell_edge['param']] = edge_params_val

    # Check parameters
    print("\nShell edges:")
    for shell_edge in shell_edges:
        print(shell_edge)
    print("\nShell edge parameters:")
    for param, edge_params_val in shell_edge_params.items():
        print(param + ':')
        print(edge_params_val)
    print("")

    # Build your shell edges into the networks
    build_edges(networks, shell_edges, shell_edge_params,
                edge_add_properties, syn)

########################## END EDGE EFFECTS ##############################
##########################################################################
# Out:
# Shell edges:
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 0}, 'target': {'pop_name': ['CP'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCP2CP_0_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 0}, 'target': {'pop_name': ['CP'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCP2CP_0_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 0}, 'target': {'pop_name': ['CP'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCP2CP_0_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 1}, 'target': {'pop_name': ['CP'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCP2CP_1_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 1}, 'target': {'pop_name': ['CP'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCP2CP_1_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 1}, 'target': {'pop_name': ['CP'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCP2CP_1_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 2}, 'target': {'pop_name': ['CP'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCP2CP_2_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 2}, 'target': {'pop_name': ['CP'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCP2CP_2_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 2}, 'target': {'pop_name': ['CP'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCP2CP_2_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 0}, 'target': {'pop_name': ['CS'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCS2CS_0_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 0}, 'target': {'pop_name': ['CS'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCS2CS_0_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 0}, 'target': {'pop_name': ['CS'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCS2CS_0_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 1}, 'target': {'pop_name': ['CS'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCS2CS_1_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 1}, 'target': {'pop_name': ['CS'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCS2CS_1_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 1}, 'target': {'pop_name': ['CS'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCS2CS_1_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 2}, 'target': {'pop_name': ['CS'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCS2CS_2_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 2}, 'target': {'pop_name': ['CS'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCS2CS_2_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 2}, 'target': {'pop_name': ['CS'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCS2CS_2_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 0}, 'target': {'pop_name': ['CS'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCP2CS_0_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 0}, 'target': {'pop_name': ['CS'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCP2CS_0_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 0}, 'target': {'pop_name': ['CS'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCP2CS_0_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 1}, 'target': {'pop_name': ['CS'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCP2CS_1_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 1}, 'target': {'pop_name': ['CS'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCP2CS_1_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 1}, 'target': {'pop_name': ['CS'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCP2CS_1_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 2}, 'target': {'pop_name': ['CS'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCP2CS_2_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 2}, 'target': {'pop_name': ['CS'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCP2CS_2_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CP'], 'assembly_id': 2}, 'target': {'pop_name': ['CS'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCP2CS_2_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CP2CS'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 0}, 'target': {'pop_name': ['CP'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCS2CP_0_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 0}, 'target': {'pop_name': ['CP'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCS2CP_0_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 0}, 'target': {'pop_name': ['CP'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCS2CP_0_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 1}, 'target': {'pop_name': ['CP'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCS2CP_1_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 1}, 'target': {'pop_name': ['CP'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCS2CP_1_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 1}, 'target': {'pop_name': ['CP'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCS2CP_1_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 2}, 'target': {'pop_name': ['CP'], 'assembly_id': 0}, 'source_network': 'shell'}, 'param': 'shellCS2CP_2_0', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 2}, 'target': {'pop_name': ['CP'], 'assembly_id': 1}, 'source_network': 'shell'}, 'param': 'shellCS2CP_2_1', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': ['CS'], 'assembly_id': 2}, 'target': {'pop_name': ['CP'], 'assembly_id': 2}, 'source_network': 'shell'}, 'param': 'shellCS2CP_2_2', 'add_properties': 'syn_dist_delay_feng_section_PN', 'assy_type': 'CS2CP'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'FSI'}, 'target': {'pop_name': 'FSI'}, 'source_network': 'shell'}, 'param': 'shellFSI2FSI', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'LTS'}, 'target': {'pop_name': 'LTS'}, 'source_network': 'shell'}, 'param': 'shellLTS2LTS', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'FSI'}, 'target': {'pop_name': 'LTS'}, 'source_network': 'shell'}, 'param': 'shellFSI2LTS', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'LTS'}, 'target': {'pop_name': 'FSI'}, 'source_network': 'shell'}, 'param': 'shellLTS2FSI', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'CP'}, 'target': {'pop_name': 'FSI'}, 'source_network': 'shell'}, 'param': 'shellCP2FSI', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'FSI'}, 'target': {'pop_name': 'CP'}, 'source_network': 'shell'}, 'param': 'shellFSI2CP', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'CS'}, 'target': {'pop_name': 'FSI'}, 'source_network': 'shell'}, 'param': 'shellCS2FSI', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'FSI'}, 'target': {'pop_name': 'CS'}, 'source_network': 'shell'}, 'param': 'shellFSI2CS', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'CP'}, 'target': {'pop_name': 'LTS'}, 'source_network': 'shell'}, 'param': 'shellCP2LTS', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'LTS'}, 'target': {'pop_name': 'CP'}, 'source_network': 'shell'}, 'param': 'shellLTS2CP', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'CS'}, 'target': {'pop_name': 'LTS'}, 'source_network': 'shell'}, 'param': 'shellCS2LTS', 'add_properties': 'syn_dist_delay_feng_default'}
# {'network': 'cortex', 'edge': {'source': {'pop_name': 'LTS'}, 'target': {'pop_name': 'CS'}, 'source_network': 'shell'}, 'param': 'shellLTS2CS', 'add_properties': 'syn_dist_delay_feng_default'}
#
# Shell edge parameters:
# shellCP2CP_0_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F5100>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_0_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F52B0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_0_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F52B0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_1_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F52B0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_1_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F5100>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_1_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F52B0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_2_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F52B0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_2_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F52B0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCP2CP_2_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BAB8F5100>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CP.json'}
# shellCS2CS_0_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1730>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_0_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1760>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_0_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1760>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_1_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1760>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_1_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1730>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_1_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1760>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_2_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1760>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_2_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1760>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCS2CS_2_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018BABAD1730>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CS.json'}
# shellCP2CS_0_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA60>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_0_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBAC0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_0_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBAC0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_1_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBAC0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_1_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA60>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_1_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBAC0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_2_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBAC0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_2_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBAC0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCP2CS_2_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA60>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CP2CS.json'}
# shellCS2CP_0_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB8E0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_0_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA00>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_0_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA00>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_1_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA00>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_1_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB8E0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_1_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA00>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_2_0:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA00>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_2_1:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBA00>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellCS2CP_2_2:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB8E0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.4, 'dynamics_params': 'CS2CP.json'}
# shellFSI2FSI:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB400>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 0, 'afferent_section_pos': 0.5, 'dynamics_params': 'FSI2FSI.json'}
# shellLTS2LTS:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB940>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 0, 'afferent_section_pos': 0.5, 'dynamics_params': 'LTS2LTS.json'}
# shellFSI2LTS:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB5B0>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 0, 'afferent_section_pos': 0.5, 'dynamics_params': 'FSI2LTS.json'}
# shellLTS2FSI:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB700>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 0, 'afferent_section_pos': 0.5, 'dynamics_params': 'LTS2FSI.json'}
# shellCP2FSI:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB790>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.5, 'dynamics_params': 'CP2FSI.json'}
# shellFSI2CP:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB190>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 0, 'afferent_section_pos': 0.5, 'dynamics_params': 'FSI2CP.json'}
# shellCS2FSI:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBD60>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.5, 'dynamics_params': 'CS2FSI.json'}
# shellFSI2CS:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB2E0>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 0, 'afferent_section_pos': 0.5, 'dynamics_params': 'FSI2CS.json'}
# shellCP2LTS:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBEE0>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.5, 'dynamics_params': 'CP2LTS.json'}
# shellLTS2CP:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CB9D0>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 2, 'afferent_section_pos': 0.8, 'dynamics_params': 'LTS2CP.json'}
# shellCS2LTS:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBF70>, 'p_arg': <function cylindrical_dist_z at 0x0000018BABAA63A0>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 1, 'afferent_section_pos': 0.5, 'dynamics_params': 'CS2LTS.json'}
# shellLTS2CS:
# {'connector_class': <class 'connectors.UnidirectionConnector'>, 'connector_params': {'p': <connectors.GaussianDropoff object at 0x0000018B9B1CBEB0>, 'p_arg': <function spherical_dist at 0x0000018BABAA6310>, 'n_syn': 1, 'verbose': True}, 'weight_function': 'lognormal_weight', 'syn_weight': 1.0, 'weight_sigma': 0.8, 'sigma_upper_bound': 3.0, 'afferent_section_id': 2, 'afferent_section_pos': 0.8, 'dynamics_params': 'LTS2CS.json'}
#
# Adding edge: shellCP2CP_0_0
# Adding edge: shellCP2CP_0_1
# Adding edge: shellCP2CP_0_2
# Adding edge: shellCP2CP_1_0
# Adding edge: shellCP2CP_1_1
# Adding edge: shellCP2CP_1_2
# Adding edge: shellCP2CP_2_0
# Adding edge: shellCP2CP_2_1
# Adding edge: shellCP2CP_2_2
# Adding edge: shellCS2CS_0_0
# Adding edge: shellCS2CS_0_1
# Adding edge: shellCS2CS_0_2
# Adding edge: shellCS2CS_1_0
# Adding edge: shellCS2CS_1_1
# Adding edge: shellCS2CS_1_2
# Adding edge: shellCS2CS_2_0
# Adding edge: shellCS2CS_2_1
# Adding edge: shellCS2CS_2_2
# Adding edge: shellCP2CS_0_0
# Adding edge: shellCP2CS_0_1
# Adding edge: shellCP2CS_0_2
# Adding edge: shellCP2CS_1_0
# Adding edge: shellCP2CS_1_1
# Adding edge: shellCP2CS_1_2
# Adding edge: shellCP2CS_2_0
# Adding edge: shellCP2CS_2_1
# Adding edge: shellCP2CS_2_2
# Adding edge: shellCS2CP_0_0
# Adding edge: shellCS2CP_0_1
# Adding edge: shellCS2CP_0_2
# Adding edge: shellCS2CP_1_0
# Adding edge: shellCS2CP_1_1
# Adding edge: shellCS2CP_1_2
# Adding edge: shellCS2CP_2_0
# Adding edge: shellCS2CP_2_1
# Adding edge: shellCS2CP_2_2
# Adding edge: shellFSI2FSI
# Adding edge: shellLTS2LTS
# Adding edge: shellFSI2LTS
# Adding edge: shellLTS2FSI
# Adding edge: shellCP2FSI
# Adding edge: shellFSI2CP
# Adding edge: shellCS2FSI
# Adding edge: shellFSI2CS
# Adding edge: shellCP2LTS
# Adding edge: shellLTS2CP
# Adding edge: shellCS2LTS
# Adding edge: shellLTS2CS

# %%
##########################################################################
############################ GAP JUNCTIONS ###############################

net = networks['cortex']

# FSI
g_gap = 0.000066  # microsiemens
# gap junction probability correlated with chemical synapse
gap_junc_FSI = CorrelatedGapJunction(
    p_non=GaussianDropoff(
        mean=min_conn_dist, stdev=98.0,
        min_dist=min_conn_dist, max_dist=max_conn_dist,
        ptotal=0.267, ptotal_dist_range=(min_conn_dist, 200.),
        dist_type='spherical'),
    p_uni=0.56, p_rec=1.,
    connector=edge_params['FSI2FSI']['connector_object']
)
population = net.nodes(pop_name='FSI')
gap_junc_FSI.setup_nodes(source=population, target=population)

conn = net.add_edges(
    is_gap_junction=True, syn_weight=g_gap, target_sections=None,
    afferent_section_id=0, afferent_section_pos=0.5,
    **gap_junc_FSI.edge_params()
)

# LTS
g_gap = 0.00076  # microsiemens
# gap junction probability uncorrelated with chemical synapse
LTS_uncorr_p = GaussianDropoff(
    mean=0., stdev=74.28,
    min_dist=min_conn_dist, max_dist=max_conn_dist,
    ptotal=0.85, ptotal_dist_range=(min_conn_dist, 50.),
    dist_type='spherical'
)
gap_junc_LTS = CorrelatedGapJunction(
    p_non=LTS_uncorr_p, p_uni=LTS_uncorr_p, p_rec=LTS_uncorr_p,
    connector=edge_params['LTS2LTS']['connector_object']
)
population = net.nodes(pop_name='LTS')
gap_junc_LTS.setup_nodes(source=population, target=population)

conn = net.add_edges(
    is_gap_junction=True, syn_weight=g_gap, target_sections=None,
    afferent_section_id=0, afferent_section_pos=0.5,
    **gap_junc_LTS.edge_params()
)

# %%
##########################################################################
###############################  BUILD  ##################################

# Save the network into the appropriate network dir
save_networks(networks, network_dir)
# Out:
# Building cortex
#
# Start building connection between:
#   cortex: pop_name=='['CP']'&assembly_id=='0'
#   cortex: pop_name=='['CP']'&assembly_id=='0'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.220
# Time for estimating rho: 0.133 sec
# Total time for creating connection matrix: 0.174 sec
# Numbers of (all, reciprocal) connections:
# Number of connected pairs: (329, 64)
# Number of possible connections: (3408)
# Fraction of connected pairs in possible ones: (9.65%, 1.88%)
# Number of total pairs: 7503
# Fraction of connected pairs in all pairs: (4.38%, 0.85%)
#
# Assigning forward connections.
# Done!
# Time for building connections: 0.012 sec
#
# Start building connection between:
#   cortex: pop_name=='['CP']'&assembly_id=='0'
#   cortex: pop_name=='['CP']'&assembly_id=='1'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.617
# Time for estimating rho: 0.290 sec
# Total time for creating connection matrix: 0.672 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (264, 245, 153)
# Number of possible connections: (8325, 8325, 8325)
# Fraction of connected pairs in possible ones: (3.17%, 2.94%, 1.84%)
# Number of total pairs: 17958
# Fraction of connected pairs in all pairs: (1.47%, 1.36%, 0.85%)
#
# Assigning forward connections.
#
# Start building connection between:
#   cortex: pop_name=='['CP']'&assembly_id=='0'
#   cortex: pop_name=='['CP']'&assembly_id=='2'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.619
# Time for estimating rho: 0.261 sec
# Total time for creating connection matrix: 0.607 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (222, 215, 142)
# Number of possible connections: (7705, 7705, 7705)
# Fraction of connected pairs in possible ones: (2.88%, 2.79%, 1.84%)
# Number of total pairs: 16113
# Fraction of connected pairs in all pairs: (1.38%, 1.33%, 0.88%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 0.823 sec
#
# Start building connection between:
#   cortex: pop_name=='['CP']'&assembly_id=='1'
#   cortex: pop_name=='['CP']'&assembly_id=='1'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.219
# Time for estimating rho: 0.216 sec
# Total time for creating connection matrix: 0.302 sec
# Numbers of (all, reciprocal) connections:
# Number of connected pairs: (487, 89)
# Number of possible connections: (4897)
# Fraction of connected pairs in possible ones: (9.94%, 1.82%)
# Number of total pairs: 10585
# Fraction of connected pairs in all pairs: (4.60%, 0.84%)
#
# Assigning forward connections.
# Done!
# Time for building connections: 0.020 sec
#
# Start building connection between:
#   cortex: pop_name=='['CP']'&assembly_id=='1'
#   cortex: pop_name=='['CP']'&assembly_id=='2'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.617
# Time for estimating rho: 0.381 sec
# Total time for creating connection matrix: 0.928 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (264, 268, 180)
# Number of possible connections: (9287, 9287, 9287)
# Fraction of connected pairs in possible ones: (2.84%, 2.89%, 1.94%)
# Number of total pairs: 19126
# Fraction of connected pairs in all pairs: (1.38%, 1.40%, 0.94%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 1.977 sec
# Assigning backward connections.
# Done!
# Time for building connections: 0.665 sec
#
# Start building connection between:
#   cortex: pop_name=='['CP']'&assembly_id=='2'
#   cortex: pop_name=='['CP']'&assembly_id=='2'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.220
# Time for estimating rho: 0.355 sec
# Total time for creating connection matrix: 0.406 sec
# Numbers of (all, reciprocal) connections:
# Number of connected pairs: (425, 79)
# Number of possible connections: (4288)
# Fraction of connected pairs in possible ones: (9.91%, 1.84%)
# Number of total pairs: 8515
# Fraction of connected pairs in all pairs: (4.99%, 0.93%)
#
# Assigning forward connections.
# Done!
# Time for building connections: 0.012 sec
#
# Start building connection between:
#   cortex: pop_name=='['CS']'&assembly_id=='0'
#   cortex: pop_name=='['CS']'&assembly_id=='0'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.014
# Time for estimating rho: 0.156 sec
# Total time for creating connection matrix: 0.199 sec
# Numbers of (all, reciprocal) connections:
# Number of connected pairs: (551, 31)
# Number of possible connections: (5116)
# Fraction of connected pairs in possible ones: (10.77%, 0.61%)
# Number of total pairs: 10296
# Fraction of connected pairs in all pairs: (5.35%, 0.30%)
#
# Assigning forward connections.
# Done!
# Time for building connections: 0.014 sec
#
# Start building connection between:
#   cortex: pop_name=='['CS']'&assembly_id=='0'
#   cortex: pop_name=='['CS']'&assembly_id=='1'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.212
# Time for estimating rho: 0.243 sec
# Total time for creating connection matrix: 0.541 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (239, 248, 63)
# Number of possible connections: (8832, 8832, 8832)
# Fraction of connected pairs in possible ones: (2.71%, 2.81%, 0.71%)
# Number of total pairs: 17280
# Fraction of connected pairs in all pairs: (1.38%, 1.44%, 0.36%)
#
# Assigning forward connections.
#
# Start building connection between:
#   cortex: pop_name=='['CS']'&assembly_id=='0'
#   cortex: pop_name=='['CS']'&assembly_id=='2'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.214
# Time for estimating rho: 0.324 sec
# Total time for creating connection matrix: 0.664 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (242, 239, 56)
# Number of possible connections: (9490, 9490, 9490)
# Fraction of connected pairs in possible ones: (2.55%, 2.52%, 0.59%)
# Number of total pairs: 19584
# Fraction of connected pairs in all pairs: (1.24%, 1.22%, 0.29%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 0.947 sec
#
# Start building connection between:
#   cortex: pop_name=='['CS']'&assembly_id=='1'
#   cortex: pop_name=='['CS']'&assembly_id=='1'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.013
# Time for estimating rho: 0.254 sec
# Total time for creating connection matrix: 0.328 sec
# Numbers of (all, reciprocal) connections:
# Number of connected pairs: (386, 16)
# Number of possible connections: (3715)
# Fraction of connected pairs in possible ones: (10.39%, 0.43%)
# Number of total pairs: 7140
# Fraction of connected pairs in all pairs: (5.41%, 0.22%)
#
# Assigning forward connections.
# Done!
# Time for building connections: 0.011 sec
#
# Start building connection between:
#   cortex: pop_name=='['CS']'&assembly_id=='1'
#   cortex: pop_name=='['CS']'&assembly_id=='2'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.212
# Time for estimating rho: 0.281 sec
# Total time for creating connection matrix: 0.507 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (216, 218, 51)
# Number of possible connections: (8271, 8271, 8271)
# Fraction of connected pairs in possible ones: (2.61%, 2.64%, 0.62%)
# Number of total pairs: 16320
# Fraction of connected pairs in all pairs: (1.32%, 1.34%, 0.31%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 1.247 sec
# Assigning backward connections.
# Done!
# Time for building connections: 0.218 sec
#
# Start building connection between:
#   cortex: pop_name=='['CS']'&assembly_id=='2'
#   cortex: pop_name=='['CS']'&assembly_id=='2'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.014
# Time for estimating rho: 0.191 sec
# Total time for creating connection matrix: 0.256 sec
# Numbers of (all, reciprocal) connections:
# Number of connected pairs: (422, 22)
# Number of possible connections: (4523)
# Fraction of connected pairs in possible ones: (9.33%, 0.49%)
# Number of total pairs: 9180
# Fraction of connected pairs in all pairs: (4.60%, 0.24%)
#
# Assigning forward connections.
# Done!
# Time for building connections: 0.013 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 51
# Number of possible connections: 8392
# Fraction of connected pairs in possible ones: 0.61%
# Number of total pairs: 17712
# Fraction of connected pairs in all pairs: 0.29%
#
# Done!
# Time for building connections: 0.313 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 22
# Number of possible connections: 7156
# Fraction of connected pairs in possible ones: 0.31%
# Number of total pairs: 14760
# Fraction of connected pairs in all pairs: 0.15%
#
# Done!
# Time for building connections: 0.366 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 24
# Number of possible connections: 7991
# Fraction of connected pairs in possible ones: 0.30%
# Number of total pairs: 16728
# Fraction of connected pairs in all pairs: 0.14%
#
# Done!
# Time for building connections: 0.336 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 27
# Number of possible connections: 10092
# Fraction of connected pairs in possible ones: 0.27%
# Number of total pairs: 21024
# Fraction of connected pairs in all pairs: 0.13%
#
# Done!
# Time for building connections: 0.441 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 60
# Number of possible connections: 8712
# Fraction of connected pairs in possible ones: 0.69%
# Number of total pairs: 17520
# Fraction of connected pairs in all pairs: 0.34%
#
# Done!
# Time for building connections: 0.357 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 36
# Number of possible connections: 9561
# Fraction of connected pairs in possible ones: 0.38%
# Number of total pairs: 19856
# Fraction of connected pairs in all pairs: 0.18%
#
# Done!
# Time for building connections: 0.411 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 28
# Number of possible connections: 9153
# Fraction of connected pairs in possible ones: 0.31%
# Number of total pairs: 18864
# Fraction of connected pairs in all pairs: 0.15%
#
# Done!
# Time for building connections: 0.479 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 22
# Number of possible connections: 8165
# Fraction of connected pairs in possible ones: 0.27%
# Number of total pairs: 15720
# Fraction of connected pairs in all pairs: 0.14%
#
# Done!
# Time for building connections: 0.296 sec
#
# Start building connection
#   from cortex: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 58
# Number of possible connections: 8854
# Fraction of connected pairs in possible ones: 0.66%
# Number of total pairs: 17816
# Fraction of connected pairs in all pairs: 0.33%
#
# Done!
# Time for building connections: 0.336 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 639
# Number of possible connections: 8392
# Fraction of connected pairs in possible ones: 7.61%
# Number of total pairs: 17712
# Fraction of connected pairs in all pairs: 3.61%
#
# Done!
# Time for building connections: 0.297 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 396
# Number of possible connections: 10092
# Fraction of connected pairs in possible ones: 3.92%
# Number of total pairs: 21024
# Fraction of connected pairs in all pairs: 1.88%
#
# Done!
# Time for building connections: 0.397 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 347
# Number of possible connections: 9153
# Fraction of connected pairs in possible ones: 3.79%
# Number of total pairs: 18864
# Fraction of connected pairs in all pairs: 1.84%
#
# Done!
# Time for building connections: 0.304 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 255
# Number of possible connections: 7156
# Fraction of connected pairs in possible ones: 3.56%
# Number of total pairs: 14760
# Fraction of connected pairs in all pairs: 1.73%
#
# Done!
# Time for building connections: 0.203 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 634
# Number of possible connections: 8712
# Fraction of connected pairs in possible ones: 7.28%
# Number of total pairs: 17520
# Fraction of connected pairs in all pairs: 3.62%
#
# Done!
# Time for building connections: 0.301 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 309
# Number of possible connections: 8165
# Fraction of connected pairs in possible ones: 3.78%
# Number of total pairs: 15720
# Fraction of connected pairs in all pairs: 1.97%
#
# Done!
# Time for building connections: 0.281 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 292
# Number of possible connections: 7991
# Fraction of connected pairs in possible ones: 3.65%
# Number of total pairs: 16728
# Fraction of connected pairs in all pairs: 1.75%
#
# Done!
# Time for building connections: 0.261 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 366
# Number of possible connections: 9561
# Fraction of connected pairs in possible ones: 3.83%
# Number of total pairs: 19856
# Fraction of connected pairs in all pairs: 1.84%
#
# Done!
# Time for building connections: 0.424 sec
#
# Start building connection
#   from cortex: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 638
# Number of possible connections: 8854
# Fraction of connected pairs in possible ones: 7.21%
# Number of total pairs: 17816
# Fraction of connected pairs in all pairs: 3.58%
#
# Done!
# Time for building connections: 0.306 sec
#
# Start building connection between:
#   cortex: pop_name=='FSI'
#   cortex: pop_name=='FSI'
# Output of p0, p0_arg will be cached.
# Estimated value of rho=0.072
# Time for estimating rho: 0.076 sec
# Total time for creating connection matrix: 0.103 sec
# Numbers of (all, reciprocal) connections:
# Number of connected pairs: (219, 26)
# Number of possible connections: (2066)
# Fraction of connected pairs in possible ones: (10.60%, 1.26%)
# Number of total pairs: 7140
# Fraction of connected pairs in all pairs: (3.07%, 0.36%)
#
# Assigning forward connections.
# Done!
# Time for building connections: 0.007 sec
#
# Start building connection
#   from cortex: pop_name=='LTS'
#   to cortex: pop_name=='LTS'
# Number of connected pairs: 79
# Number of possible connections: 1940
# Fraction of connected pairs in possible ones: 4.07%
# Number of total pairs: 6400
# Fraction of connected pairs in all pairs: 1.23%
#
# Done!
# Time for building connections: 0.122 sec
#
# Start building connection between:
#   cortex: pop_name=='FSI'
#   cortex: pop_name=='LTS'
# Output of p1, p1_arg, p0, p0_arg will be cached.
# Estimated value of rho=0.162
# Time for estimating rho: 0.308 sec
# Total time for creating connection matrix: 0.543 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (268, 437, 108)
# Number of possible connections: (2907, 2907, 2907)
# Fraction of connected pairs in possible ones: (9.22%, 15.03%, 3.72%)
# Number of total pairs: 9600
# Fraction of connected pairs in all pairs: (2.79%, 4.55%, 1.12%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 0.095 sec
#
# Start building connection between:
#   cortex: pop_name=='CP'
#   cortex: pop_name=='FSI'
# Output of p1, p1_arg, p0, p0_arg will be cached.
# Estimated value of rho=0.405
# Time for estimating rho: 1.326 sec
# Total time for creating connection matrix: 2.171 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (2469, 1587, 849)
# Number of possible connections: (22499, 14820, 14820)
# Fraction of connected pairs in possible ones: (10.97%, 10.71%, 5.73%)
# Number of total pairs: 48000
# Fraction of connected pairs in all pairs: (5.14%, 3.31%, 1.77%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 0.327 sec
#
# Start building connection between:
#   cortex: pop_name=='CS'
#   cortex: pop_name=='FSI'
# Output of p1, p1_arg, p0, p0_arg will be cached.
# Estimated value of rho=0.425
# Time for estimating rho: 1.443 sec
# Total time for creating connection matrix: 2.205 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (1747, 1171, 596)
# Number of possible connections: (22937, 14901, 14901)
# Fraction of connected pairs in possible ones: (7.62%, 7.86%, 4.00%)
# Number of total pairs: 48000
# Fraction of connected pairs in all pairs: (3.64%, 2.44%, 1.24%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 0.382 sec
#
# Start building connection between:
#   cortex: pop_name=='CP'
#   cortex: pop_name=='LTS'
# Output of p1, p1_arg, p0, p0_arg will be cached.
# Estimated value of rho=0.186
# Time for estimating rho: 0.814 sec
# Total time for creating connection matrix: 1.159 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (1470, 801, 299)
# Number of possible connections: (15267, 9637, 9637)
# Fraction of connected pairs in possible ones: (9.63%, 8.31%, 3.10%)
# Number of total pairs: 32000
# Fraction of connected pairs in all pairs: (4.59%, 2.50%, 0.93%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 0.187 sec
#
# Start building connection between:
#   cortex: pop_name=='CS'
#   cortex: pop_name=='LTS'
# Output of p1, p1_arg, p0, p0_arg will be cached.
# Estimated value of rho=0.467
# Time for estimating rho: 0.800 sec
# Total time for creating connection matrix: 1.216 sec
# Numbers of (forward, backward, reciprocal) connections:
# Number of connected pairs: (686, 219, 161)
# Number of possible connections: (15618, 10691, 10691)
# Fraction of connected pairs in possible ones: (4.39%, 2.05%, 1.51%)
# Number of total pairs: 32000
# Fraction of connected pairs in all pairs: (2.14%, 0.68%, 0.50%)
#
# Assigning forward connections.
# Assigning backward connections.
# Done!
# Time for building connections: 0.178 sec
#
# Start building connection from thalamus: *
#   0. to cortex: pop_name=='CP'
#     Time for this partition: 0.409 sec
#   1. to cortex: pop_name=='CS'
#     Time for this partition: 0.400 sec
# Done!
# Time for building connections: 0.823 sec
#
# Start building connection from baseline: *
#   0. to cortex: pop_name=='CP'
#     Time for this partition: 0.381 sec
#   1. to cortex: pop_name=='CS'
#     Time for this partition: 0.433 sec
#   2. to cortex: pop_name=='FSI'
#     Time for this partition: 0.115 sec
#   3. to cortex: pop_name=='LTS'
#     Time for this partition: 0.100 sec
# Done!
# Time for building connections: 1.052 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 199
# Number of possible connections: 5056
# Fraction of connected pairs in possible ones: 3.94%
# Number of total pairs: 50307
# Fraction of connected pairs in all pairs: 0.40%
#
# Done!
# Time for building connections: 0.676 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 100
# Number of possible connections: 5914
# Fraction of connected pairs in possible ones: 1.69%
# Number of total pairs: 59714
# Fraction of connected pairs in all pairs: 0.17%
#
# Done!
# Time for building connections: 0.921 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 116
# Number of possible connections: 5102
# Fraction of connected pairs in possible ones: 2.27%
# Number of total pairs: 53579
# Fraction of connected pairs in all pairs: 0.22%
#
# Done!
# Time for building connections: 0.922 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 118
# Number of possible connections: 5449
# Fraction of connected pairs in possible ones: 2.17%
# Number of total pairs: 48708
# Fraction of connected pairs in all pairs: 0.24%
#
# Done!
# Time for building connections: 0.670 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 225
# Number of possible connections: 6284
# Fraction of connected pairs in possible ones: 3.58%
# Number of total pairs: 57816
# Fraction of connected pairs in all pairs: 0.39%
#
# Done!
# Time for building connections: 0.811 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 95
# Number of possible connections: 5481
# Fraction of connected pairs in possible ones: 1.73%
# Number of total pairs: 51876
# Fraction of connected pairs in all pairs: 0.18%
#
# Done!
# Time for building connections: 0.677 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 98
# Number of possible connections: 5290
# Fraction of connected pairs in possible ones: 1.85%
# Number of total pairs: 49323
# Fraction of connected pairs in all pairs: 0.20%
#
# Done!
# Time for building connections: 0.600 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 108
# Number of possible connections: 6254
# Fraction of connected pairs in possible ones: 1.73%
# Number of total pairs: 58546
# Fraction of connected pairs in all pairs: 0.18%
#
# Done!
# Time for building connections: 0.673 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 171
# Number of possible connections: 5137
# Fraction of connected pairs in possible ones: 3.33%
# Number of total pairs: 52531
# Fraction of connected pairs in all pairs: 0.33%
#
# Done!
# Time for building connections: 0.607 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 213
# Number of possible connections: 5695
# Fraction of connected pairs in possible ones: 3.74%
# Number of total pairs: 58032
# Fraction of connected pairs in all pairs: 0.37%
#
# Done!
# Time for building connections: 0.753 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 71
# Number of possible connections: 4470
# Fraction of connected pairs in possible ones: 1.59%
# Number of total pairs: 48360
# Fraction of connected pairs in all pairs: 0.15%
#
# Done!
# Time for building connections: 0.690 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 87
# Number of possible connections: 5397
# Fraction of connected pairs in possible ones: 1.61%
# Number of total pairs: 54808
# Fraction of connected pairs in all pairs: 0.16%
#
# Done!
# Time for building connections: 2.390 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 93
# Number of possible connections: 5951
# Fraction of connected pairs in possible ones: 1.56%
# Number of total pairs: 59760
# Fraction of connected pairs in all pairs: 0.16%
#
# Done!
# Time for building connections: 1.407 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 145
# Number of possible connections: 4741
# Fraction of connected pairs in possible ones: 3.06%
# Number of total pairs: 49800
# Fraction of connected pairs in all pairs: 0.29%
#
# Done!
# Time for building connections: 0.890 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 96
# Number of possible connections: 5641
# Fraction of connected pairs in possible ones: 1.70%
# Number of total pairs: 56440
# Fraction of connected pairs in all pairs: 0.17%
#
# Done!
# Time for building connections: 1.629 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 89
# Number of possible connections: 5676
# Fraction of connected pairs in possible ones: 1.57%
# Number of total pairs: 59184
# Fraction of connected pairs in all pairs: 0.15%
#
# Done!
# Time for building connections: 0.923 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 83
# Number of possible connections: 4550
# Fraction of connected pairs in possible ones: 1.82%
# Number of total pairs: 49320
# Fraction of connected pairs in all pairs: 0.17%
#
# Done!
# Time for building connections: 0.603 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 202
# Number of possible connections: 5533
# Fraction of connected pairs in possible ones: 3.65%
# Number of total pairs: 55896
# Fraction of connected pairs in all pairs: 0.36%
#
# Done!
# Time for building connections: 0.679 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 28
# Number of possible connections: 5602
# Fraction of connected pairs in possible ones: 0.50%
# Number of total pairs: 58896
# Fraction of connected pairs in all pairs: 0.05%
#
# Done!
# Time for building connections: 0.846 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 6
# Number of possible connections: 4506
# Fraction of connected pairs in possible ones: 0.13%
# Number of total pairs: 49080
# Fraction of connected pairs in all pairs: 0.01%
#
# Done!
# Time for building connections: 0.619 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='0'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 4
# Number of possible connections: 5335
# Fraction of connected pairs in possible ones: 0.07%
# Number of total pairs: 55624
# Fraction of connected pairs in all pairs: 0.01%
#
# Done!
# Time for building connections: 1.061 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 20
# Number of possible connections: 6008
# Fraction of connected pairs in possible ones: 0.33%
# Number of total pairs: 57024
# Fraction of connected pairs in all pairs: 0.04%
#
# Done!
# Time for building connections: 1.160 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 21
# Number of possible connections: 4788
# Fraction of connected pairs in possible ones: 0.44%
# Number of total pairs: 47520
# Fraction of connected pairs in all pairs: 0.04%
#
# Done!
# Time for building connections: 0.933 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='1'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 19
# Number of possible connections: 5838
# Fraction of connected pairs in possible ones: 0.33%
# Number of total pairs: 53856
# Fraction of connected pairs in all pairs: 0.04%
#
# Done!
# Time for building connections: 0.801 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='0'
# Number of connected pairs: 11
# Number of possible connections: 5830
# Fraction of connected pairs in possible ones: 0.19%
# Number of total pairs: 57744
# Fraction of connected pairs in all pairs: 0.02%
#
# Done!
# Time for building connections: 0.827 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='1'
# Number of connected pairs: 12
# Number of possible connections: 4634
# Fraction of connected pairs in possible ones: 0.26%
# Number of total pairs: 48120
# Fraction of connected pairs in all pairs: 0.02%
#
# Done!
# Time for building connections: 0.550 sec
#
# Start building connection
#   from shell: pop_name=='['CP']'&assembly_id=='2'
#   to cortex: pop_name=='['CS']'&assembly_id=='2'
# Number of connected pairs: 19
# Number of possible connections: 5446
# Fraction of connected pairs in possible ones: 0.35%
# Number of total pairs: 54536
# Fraction of connected pairs in all pairs: 0.03%
#
# Done!
# Time for building connections: 0.637 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 270
# Number of possible connections: 5116
# Fraction of connected pairs in possible ones: 5.28%
# Number of total pairs: 49569
# Fraction of connected pairs in all pairs: 0.54%
#
# Done!
# Time for building connections: 0.592 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 143
# Number of possible connections: 5970
# Fraction of connected pairs in possible ones: 2.40%
# Number of total pairs: 58838
# Fraction of connected pairs in all pairs: 0.24%
#
# Done!
# Time for building connections: 0.833 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='0'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 111
# Number of possible connections: 5018
# Fraction of connected pairs in possible ones: 2.21%
# Number of total pairs: 52793
# Fraction of connected pairs in all pairs: 0.21%
#
# Done!
# Time for building connections: 0.646 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 148
# Number of possible connections: 5464
# Fraction of connected pairs in possible ones: 2.71%
# Number of total pairs: 51045
# Fraction of connected pairs in all pairs: 0.29%
#
# Done!
# Time for building connections: 0.595 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 311
# Number of possible connections: 6279
# Fraction of connected pairs in possible ones: 4.95%
# Number of total pairs: 60590
# Fraction of connected pairs in all pairs: 0.51%
#
# Done!
# Time for building connections: 0.692 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='1'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 131
# Number of possible connections: 5375
# Fraction of connected pairs in possible ones: 2.44%
# Number of total pairs: 54365
# Fraction of connected pairs in all pairs: 0.24%
#
# Done!
# Time for building connections: 0.968 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='0'
# Number of connected pairs: 134
# Number of possible connections: 5095
# Fraction of connected pairs in possible ones: 2.63%
# Number of total pairs: 50553
# Fraction of connected pairs in all pairs: 0.27%
#
# Done!
# Time for building connections: 1.214 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='1'
# Number of connected pairs: 149
# Number of possible connections: 5896
# Fraction of connected pairs in possible ones: 2.53%
# Number of total pairs: 60006
# Fraction of connected pairs in all pairs: 0.25%
#
# Done!
# Time for building connections: 1.577 sec
#
# Start building connection
#   from shell: pop_name=='['CS']'&assembly_id=='2'
#   to cortex: pop_name=='['CP']'&assembly_id=='2'
# Number of connected pairs: 254
# Number of possible connections: 5111
# Fraction of connected pairs in possible ones: 4.97%
# Number of total pairs: 53841
# Fraction of connected pairs in all pairs: 0.47%
#
# Done!
# Time for building connections: 0.949 sec
#
# Start building connection
#   from shell: pop_name=='FSI'
#   to cortex: pop_name=='FSI'
# Number of connected pairs: 218
# Number of possible connections: 4742
# Fraction of connected pairs in possible ones: 4.60%
# Number of total pairs: 112320
# Fraction of connected pairs in all pairs: 0.19%
#
# Done!
# Time for building connections: 1.569 sec
#
# Start building connection
#   from shell: pop_name=='LTS'
#   to cortex: pop_name=='LTS'
# Number of connected pairs: 57
# Number of possible connections: 2060
# Fraction of connected pairs in possible ones: 2.77%
# Number of total pairs: 49920
# Fraction of connected pairs in all pairs: 0.11%
#
# Done!
# Time for building connections: 0.531 sec
#
# Start building connection
#   from shell: pop_name=='FSI'
#   to cortex: pop_name=='LTS'
# Number of connected pairs: 226
# Number of possible connections: 3096
# Fraction of connected pairs in possible ones: 7.30%
# Number of total pairs: 74880
# Fraction of connected pairs in all pairs: 0.30%
#
# Done!
# Time for building connections: 0.846 sec
#
# Start building connection
#   from shell: pop_name=='LTS'
#   to cortex: pop_name=='FSI'
# Number of connected pairs: 349
# Number of possible connections: 3244
# Fraction of connected pairs in possible ones: 10.76%
# Number of total pairs: 74880
# Fraction of connected pairs in all pairs: 0.47%
#
# Done!
# Time for building connections: 0.926 sec
#
# Start building connection
#   from shell: pop_name=='CP'
#   to cortex: pop_name=='FSI'
# Number of connected pairs: 929
# Number of possible connections: 15456
# Fraction of connected pairs in possible ones: 6.01%
# Number of total pairs: 144720
# Fraction of connected pairs in all pairs: 0.64%
#
# Done!
# Time for building connections: 1.774 sec
#
# Start building connection
#   from shell: pop_name=='FSI'
#   to cortex: pop_name=='CP'
# Number of connected pairs: 837
# Number of possible connections: 14434
# Fraction of connected pairs in possible ones: 5.80%
# Number of total pairs: 374400
# Fraction of connected pairs in all pairs: 0.22%
#
# Done!
# Time for building connections: 8.067 sec
#
# Start building connection
#   from shell: pop_name=='CS'
#   to cortex: pop_name=='FSI'
# Number of connected pairs: 641
# Number of possible connections: 15534
# Fraction of connected pairs in possible ones: 4.13%
# Number of total pairs: 147480
# Fraction of connected pairs in all pairs: 0.43%
#
# Done!
# Time for building connections: 2.775 sec
#
# Start building connection
#   from shell: pop_name=='FSI'
#   to cortex: pop_name=='CS'
# Number of connected pairs: 673
# Number of possible connections: 15780
# Fraction of connected pairs in possible ones: 4.26%
# Number of total pairs: 374400
# Fraction of connected pairs in all pairs: 0.18%
#
# Done!
# Time for building connections: 5.751 sec
#
# Start building connection
#   from shell: pop_name=='CP'
#   to cortex: pop_name=='LTS'
# Number of connected pairs: 514
# Number of possible connections: 10040
# Fraction of connected pairs in possible ones: 5.12%
# Number of total pairs: 96480
# Fraction of connected pairs in all pairs: 0.53%
#
# Done!
# Time for building connections: 2.104 sec
#
# Start building connection
#   from shell: pop_name=='LTS'
#   to cortex: pop_name=='CP'
# Number of connected pairs: 531
# Number of possible connections: 10479
# Fraction of connected pairs in possible ones: 5.07%
# Number of total pairs: 249600
# Fraction of connected pairs in all pairs: 0.21%
#
# Done!
# Time for building connections: 3.981 sec
#
# Start building connection
#   from shell: pop_name=='CS'
#   to cortex: pop_name=='LTS'
# Number of connected pairs: 243
# Number of possible connections: 9911
# Fraction of connected pairs in possible ones: 2.45%
# Number of total pairs: 98320
# Fraction of connected pairs in all pairs: 0.25%
#
# Done!
# Time for building connections: 1.304 sec
#
# Start building connection
#   from shell: pop_name=='LTS'
#   to cortex: pop_name=='CS'
# Number of connected pairs: 94
# Number of possible connections: 10488
# Fraction of connected pairs in possible ones: 0.90%
# Number of total pairs: 249600
# Fraction of connected pairs in all pairs: 0.04%
#
# Done!
# Time for building connections: 3.246 sec
#
# Start building gap junction
#   in cortex: pop_name=='FSI'
# Number of connected pairs: 374
# Number of possible connections: 2066
# Fraction of connected pairs in possible ones: 18.10%
# Number of total pairs: 7140
# Fraction of connected pairs in all pairs: 5.24%
#
# Done!
# Time for building connections: 0.153 sec
#
# Start building gap junction
#   in cortex: pop_name=='LTS'
# Number of connected pairs: 64
# Number of possible connections: 970
# Fraction of connected pairs in possible ones: 6.60%
# Number of total pairs: 3160
# Fraction of connected pairs in all pairs: 2.03%
#
# Done!
# Time for building connections: 0.074 sec
# WARNING:root:No edges have been made for this network, skipping saving of edges file.
# WARNING:root:No edges have been made for this network, skipping saving of edges file.
# WARNING:root:No edges have been made for this network, skipping saving of edges file.
# Building thalamus
# Building baseline
# Building shell

# %%
from bmtool.util import util

nodes = util.load_nodes_from_config("config.json")

nodes['cortex']
# nodes['shell']
# Out:
#          node_type_id   model_type pop_name  assembly_id morphology  \
# node_id
# 0                 100  biophysical       CP            0  blank.swc
# 1                 100  biophysical       CP            2  blank.swc
# 2                 100  biophysical       CP            2  blank.swc
# 3                 100  biophysical       CP            2  blank.swc
# 4                 100  biophysical       CP            2  blank.swc
# ...               ...          ...      ...          ...        ...
# 995               107  biophysical      LTS           -1  blank.swc
# 996               107  biophysical      LTS           -1  blank.swc
# 997               107  biophysical      LTS           -1  blank.swc
# 998               107  biophysical      LTS           -1  blank.swc
# 999               107  biophysical      LTS           -1  blank.swc
#
#         model_template       pos_x       pos_y       pos_z
# node_id
# 0          hoc:CP_Cell   21.659373 -173.452236  112.721171
# 1          hoc:CP_Cell  -76.044658 -226.319644  178.527071
# 2          hoc:CP_Cell  237.822362  210.988082  143.489208
# 3          hoc:CP_Cell   48.545894 -129.554929  217.789822
# 4          hoc:CP_Cell  135.622795  299.460045  108.413903
# ...                ...         ...         ...         ...
# 995       hoc:LTS_Cell -136.240513 -294.308212 -240.429662
# 996       hoc:LTS_Cell   -8.666228 -189.613236  -27.603894
# 997       hoc:LTS_Cell  -92.736661 -156.228701  -43.661193
# 998       hoc:LTS_Cell -257.395009  -24.518762  -14.224361
# 999       hoc:LTS_Cell   80.244752  267.742073 -180.031380
#
# [1000 rows x 9 columns]

# %%
# import h5py

# f = h5py.File('./network/cortex_nodes.h5')
# f.visit(print)
