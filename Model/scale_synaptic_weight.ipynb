# %%
import numpy as np
import pandas as pd
import os

from bmtool.util.util import load_nodes_from_paths

network_dir = 'network'

# Must set to the same as in build_network.py
prob_ratio = 2  # ratio of connection probability within vs. between assemblies

wsyn_ratio = 2  # ratio of mean synaptic weigth within vs. between assemblies

# %% [markdown]
# ### Get number of population nodes

# %%
network = 'cortex'
node_files = [{"nodes_file": "cortex_nodes.h5", "node_types_file": "cortex_node_types.csv"}]
for d in node_files:
    for k, f in d.items():
        d[k] = os.path.join(network_dir, f)

node_df = load_nodes_from_paths(node_files)[network]

PN_pop_names = ['CP', 'CS']
num_CP, num_CS = [sum(node_df['pop_name'] == p) for p in PN_pop_names]
num_PN = num_CP + num_CS

# %% [markdown]
# ### Get edges info
# #### Apply scaling to both core-to-core and shell-to-core

# %%
# edges_file = 'cortex_cortex_edge_types.csv'
edges_file = 'shell_cortex_edge_types.csv'

edges_df = pd.read_csv(os.path.join(network_dir, edges_file), delimiter=' ', index_col='edge_type_id')

# %%
def get_query(s):
    condstr = s.split('&')
    cond = {}
    for c in condstr:
        key, val = c.split('==')
        cond[key] = eval(val[1:-1])
    return cond

PN_conn = {}
src_trg_query = ['source_query', 'target_query']
for i, row in edges_df.iterrows():
    conn = {}
    for query in src_trg_query:
        s = row[query]
        if 'assembly_id' in s:
            for k, v in get_query(s).items():
                conn[(query, k)] = v
    if conn:
        PN_conn[i] = conn

PN_conn = pd.DataFrame.from_dict(PN_conn, orient='index')

# %% [markdown]
# ### Estimate scaling factor of synaptic weights to maintain overall input to each cell

# %%
n_assemblies = PN_conn['target_query', 'assembly_id'].unique().size

# Scaling factor of connection probabilities for PN assemblies
# proportion of presynapstic cells in an assembly
assy_prop = (num_PN / n_assemblies - 1) / (num_PN - 1)
# Scale connection probability according to assembly
# If n_assemblies is 1, all PNs belong to the same assembly. Scaling factor is 1.
p_diff_scale = 1 / (assy_prop * (prob_ratio - 1) + 1)  # between assemblies
p_same_scale = p_diff_scale * prob_ratio  # within the same assembly

# Scaling factor of mean synaptic weigth for PN assemblies
g_diff_scale = 1 / (assy_prop * p_same_scale * wsyn_ratio + (1 - assy_prop) * p_diff_scale)  # between assemblies
g_same_scale = wsyn_ratio * g_diff_scale  # within the same assembly

# %%
same_assy = PN_conn['source_query', 'assembly_id'] == PN_conn['target_query', 'assembly_id']
diff_assy = edges_df.loc[same_assy.index].loc[~same_assy].index
same_assy = edges_df.loc[same_assy.index].loc[same_assy].index

scale_cols = ['syn_weight', 'weight_sigma']
edges_scaled_df = edges_df.copy()
edges_scaled_df.loc[diff_assy, scale_cols] *= g_diff_scale
edges_scaled_df.loc[same_assy, scale_cols] *= g_same_scale

display(edges_scaled_df)
# Out:
#                                      target_query  \
# edge_type_id
# 154           pop_name=='['CP']'&assembly_id=='0'
# 155           pop_name=='['CP']'&assembly_id=='1'
# 156           pop_name=='['CP']'&assembly_id=='2'
# 157           pop_name=='['CP']'&assembly_id=='0'
# 158           pop_name=='['CP']'&assembly_id=='1'
# 159           pop_name=='['CP']'&assembly_id=='2'
# 160           pop_name=='['CP']'&assembly_id=='0'
# 161           pop_name=='['CP']'&assembly_id=='1'
# 162           pop_name=='['CP']'&assembly_id=='2'
# 163           pop_name=='['CS']'&assembly_id=='0'
# 164           pop_name=='['CS']'&assembly_id=='1'
# 165           pop_name=='['CS']'&assembly_id=='2'
# 166           pop_name=='['CS']'&assembly_id=='0'
# 167           pop_name=='['CS']'&assembly_id=='1'
# 168           pop_name=='['CS']'&assembly_id=='2'
# 169           pop_name=='['CS']'&assembly_id=='0'
# 170           pop_name=='['CS']'&assembly_id=='1'
# 171           pop_name=='['CS']'&assembly_id=='2'
# 172           pop_name=='['CS']'&assembly_id=='0'
# 173           pop_name=='['CS']'&assembly_id=='1'
# 174           pop_name=='['CS']'&assembly_id=='2'
# 175           pop_name=='['CS']'&assembly_id=='0'
# 176           pop_name=='['CS']'&assembly_id=='1'
# 177           pop_name=='['CS']'&assembly_id=='2'
# 178           pop_name=='['CS']'&assembly_id=='0'
# 179           pop_name=='['CS']'&assembly_id=='1'
# 180           pop_name=='['CS']'&assembly_id=='2'
# 181           pop_name=='['CP']'&assembly_id=='0'
# 182           pop_name=='['CP']'&assembly_id=='1'
# 183           pop_name=='['CP']'&assembly_id=='2'
# 184           pop_name=='['CP']'&assembly_id=='0'
# 185           pop_name=='['CP']'&assembly_id=='1'
# 186           pop_name=='['CP']'&assembly_id=='2'
# 187           pop_name=='['CP']'&assembly_id=='0'
# 188           pop_name=='['CP']'&assembly_id=='1'
# 189           pop_name=='['CP']'&assembly_id=='2'
# 190                           pop_name=='['FSI']'
# 191                           pop_name=='['LTS']'
# 192                           pop_name=='['LTS']'
# 193                           pop_name=='['FSI']'
# 194                           pop_name=='['FSI']'
# 195                            pop_name=='['CP']'
# 196                           pop_name=='['FSI']'
# 197                            pop_name=='['CS']'
# 198                           pop_name=='['LTS']'
# 199                            pop_name=='['CP']'
# 200                           pop_name=='['LTS']'
# 201                            pop_name=='['CS']'
#
#                                      source_query  weight_sigma  \
# edge_type_id
# 154           pop_name=='['CP']'&assembly_id=='0'      1.066733
# 155           pop_name=='['CP']'&assembly_id=='0'      0.533367
# 156           pop_name=='['CP']'&assembly_id=='0'      0.533367
# 157           pop_name=='['CP']'&assembly_id=='1'      0.533367
# 158           pop_name=='['CP']'&assembly_id=='1'      1.066733
# 159           pop_name=='['CP']'&assembly_id=='1'      0.533367
# 160           pop_name=='['CP']'&assembly_id=='2'      0.533367
# 161           pop_name=='['CP']'&assembly_id=='2'      0.533367
# 162           pop_name=='['CP']'&assembly_id=='2'      1.066733
# 163           pop_name=='['CS']'&assembly_id=='0'      1.066733
# 164           pop_name=='['CS']'&assembly_id=='0'      0.533367
# 165           pop_name=='['CS']'&assembly_id=='0'      0.533367
# 166           pop_name=='['CS']'&assembly_id=='1'      0.533367
# 167           pop_name=='['CS']'&assembly_id=='1'      1.066733
# 168           pop_name=='['CS']'&assembly_id=='1'      0.533367
# 169           pop_name=='['CS']'&assembly_id=='2'      0.533367
# 170           pop_name=='['CS']'&assembly_id=='2'      0.533367
# 171           pop_name=='['CS']'&assembly_id=='2'      1.066733
# 172           pop_name=='['CP']'&assembly_id=='0'      1.066733
# 173           pop_name=='['CP']'&assembly_id=='0'      0.533367
# 174           pop_name=='['CP']'&assembly_id=='0'      0.533367
# 175           pop_name=='['CP']'&assembly_id=='1'      0.533367
# 176           pop_name=='['CP']'&assembly_id=='1'      1.066733
# 177           pop_name=='['CP']'&assembly_id=='1'      0.533367
# 178           pop_name=='['CP']'&assembly_id=='2'      0.533367
# 179           pop_name=='['CP']'&assembly_id=='2'      0.533367
# 180           pop_name=='['CP']'&assembly_id=='2'      1.066733
# 181           pop_name=='['CS']'&assembly_id=='0'      1.066733
# 182           pop_name=='['CS']'&assembly_id=='0'      0.533367
# 183           pop_name=='['CS']'&assembly_id=='0'      0.533367
# 184           pop_name=='['CS']'&assembly_id=='1'      0.533367
# 185           pop_name=='['CS']'&assembly_id=='1'      1.066733
# 186           pop_name=='['CS']'&assembly_id=='1'      0.533367
# 187           pop_name=='['CS']'&assembly_id=='2'      0.533367
# 188           pop_name=='['CS']'&assembly_id=='2'      0.533367
# 189           pop_name=='['CS']'&assembly_id=='2'      1.066733
# 190                           pop_name=='['FSI']'      0.800000
# 191                           pop_name=='['LTS']'      0.800000
# 192                           pop_name=='['FSI']'      0.800000
# 193                           pop_name=='['LTS']'      0.800000
# 194                            pop_name=='['CP']'      0.800000
# 195                           pop_name=='['FSI']'      0.800000
# 196                            pop_name=='['CS']'      0.800000
# 197                           pop_name=='['FSI']'      0.800000
# 198                            pop_name=='['CP']'      0.800000
# 199                           pop_name=='['LTS']'      0.800000
# 200                            pop_name=='['CS']'      0.800000
# 201                           pop_name=='['LTS']'      0.800000
#
#              model_template  afferent_section_pos  sigma_upper_bound  \
# edge_type_id
# 154           AMPA_NMDA_STP                   0.4                3.0
# 155           AMPA_NMDA_STP                   0.4                3.0
# 156           AMPA_NMDA_STP                   0.4                3.0
# 157           AMPA_NMDA_STP                   0.4                3.0
# 158           AMPA_NMDA_STP                   0.4                3.0
# 159           AMPA_NMDA_STP                   0.4                3.0
# 160           AMPA_NMDA_STP                   0.4                3.0
# 161           AMPA_NMDA_STP                   0.4                3.0
# 162           AMPA_NMDA_STP                   0.4                3.0
# 163           AMPA_NMDA_STP                   0.4                3.0
# 164           AMPA_NMDA_STP                   0.4                3.0
# 165           AMPA_NMDA_STP                   0.4                3.0
# 166           AMPA_NMDA_STP                   0.4                3.0
# 167           AMPA_NMDA_STP                   0.4                3.0
# 168           AMPA_NMDA_STP                   0.4                3.0
# 169           AMPA_NMDA_STP                   0.4                3.0
# 170           AMPA_NMDA_STP                   0.4                3.0
# 171           AMPA_NMDA_STP                   0.4                3.0
# 172           AMPA_NMDA_STP                   0.4                3.0
# 173           AMPA_NMDA_STP                   0.4                3.0
# 174           AMPA_NMDA_STP                   0.4                3.0
# 175           AMPA_NMDA_STP                   0.4                3.0
# 176           AMPA_NMDA_STP                   0.4                3.0
# 177           AMPA_NMDA_STP                   0.4                3.0
# 178           AMPA_NMDA_STP                   0.4                3.0
# 179           AMPA_NMDA_STP                   0.4                3.0
# 180           AMPA_NMDA_STP                   0.4                3.0
# 181           AMPA_NMDA_STP                   0.4                3.0
# 182           AMPA_NMDA_STP                   0.4                3.0
# 183           AMPA_NMDA_STP                   0.4                3.0
# 184           AMPA_NMDA_STP                   0.4                3.0
# 185           AMPA_NMDA_STP                   0.4                3.0
# 186           AMPA_NMDA_STP                   0.4                3.0
# 187           AMPA_NMDA_STP                   0.4                3.0
# 188           AMPA_NMDA_STP                   0.4                3.0
# 189           AMPA_NMDA_STP                   0.4                3.0
# 190             GABA_AB_STP                   0.5                3.0
# 191             GABA_AB_STP                   0.5                3.0
# 192             GABA_AB_STP                   0.5                3.0
# 193             GABA_AB_STP                   0.5                3.0
# 194           AMPA_NMDA_STP                   0.5                3.0
# 195             GABA_AB_STP                   0.5                3.0
# 196           AMPA_NMDA_STP                   0.5                3.0
# 197             GABA_AB_STP                   0.5                3.0
# 198           AMPA_NMDA_STP                   0.5                3.0
# 199             GABA_AB_STP                   0.8                3.0
# 200           AMPA_NMDA_STP                   0.5                3.0
# 201             GABA_AB_STP                   0.8                3.0
#
#              dynamics_params  afferent_section_id  syn_weight  \
# edge_type_id
# 154               CP2CP.json                    1    1.333417
# 155               CP2CP.json                    1    0.666708
# 156               CP2CP.json                    1    0.666708
# 157               CP2CP.json                    1    0.666708
# 158               CP2CP.json                    1    1.333417
# 159               CP2CP.json                    1    0.666708
# 160               CP2CP.json                    1    0.666708
# 161               CP2CP.json                    1    0.666708
# 162               CP2CP.json                    1    1.333417
# 163               CS2CS.json                    1    1.333417
# 164               CS2CS.json                    1    0.666708
# 165               CS2CS.json                    1    0.666708
# 166               CS2CS.json                    1    0.666708
# 167               CS2CS.json                    1    1.333417
# 168               CS2CS.json                    1    0.666708
# 169               CS2CS.json                    1    0.666708
# 170               CS2CS.json                    1    0.666708
# 171               CS2CS.json                    1    1.333417
# 172               CP2CS.json                    1    1.333417
# 173               CP2CS.json                    1    0.666708
# 174               CP2CS.json                    1    0.666708
# 175               CP2CS.json                    1    0.666708
# 176               CP2CS.json                    1    1.333417
# 177               CP2CS.json                    1    0.666708
# 178               CP2CS.json                    1    0.666708
# 179               CP2CS.json                    1    0.666708
# 180               CP2CS.json                    1    1.333417
# 181               CS2CP.json                    1    1.333417
# 182               CS2CP.json                    1    0.666708
# 183               CS2CP.json                    1    0.666708
# 184               CS2CP.json                    1    0.666708
# 185               CS2CP.json                    1    1.333417
# 186               CS2CP.json                    1    0.666708
# 187               CS2CP.json                    1    0.666708
# 188               CS2CP.json                    1    0.666708
# 189               CS2CP.json                    1    1.333417
# 190             FSI2FSI.json                    0    1.000000
# 191             LTS2LTS.json                    0    1.000000
# 192             FSI2LTS.json                    0    1.000000
# 193             LTS2FSI.json                    0    1.000000
# 194              CP2FSI.json                    1    1.000000
# 195              FSI2CP.json                    0    1.000000
# 196              CS2FSI.json                    1    1.000000
# 197              FSI2CS.json                    0    1.000000
# 198              CP2LTS.json                    1    1.000000
# 199              LTS2CP.json                    2    1.000000
# 200              CS2LTS.json                    1    1.000000
# 201              LTS2CS.json                    2    1.000000
#
#                weight_function
# edge_type_id
# 154           lognormal_weight
# 155           lognormal_weight
# 156           lognormal_weight
# 157           lognormal_weight
# 158           lognormal_weight
# 159           lognormal_weight
# 160           lognormal_weight
# 161           lognormal_weight
# 162           lognormal_weight
# 163           lognormal_weight
# 164           lognormal_weight
# 165           lognormal_weight
# 166           lognormal_weight
# 167           lognormal_weight
# 168           lognormal_weight
# 169           lognormal_weight
# 170           lognormal_weight
# 171           lognormal_weight
# 172           lognormal_weight
# 173           lognormal_weight
# 174           lognormal_weight
# 175           lognormal_weight
# 176           lognormal_weight
# 177           lognormal_weight
# 178           lognormal_weight
# 179           lognormal_weight
# 180           lognormal_weight
# 181           lognormal_weight
# 182           lognormal_weight
# 183           lognormal_weight
# 184           lognormal_weight
# 185           lognormal_weight
# 186           lognormal_weight
# 187           lognormal_weight
# 188           lognormal_weight
# 189           lognormal_weight
# 190           lognormal_weight
# 191           lognormal_weight
# 192           lognormal_weight
# 193           lognormal_weight
# 194           lognormal_weight
# 195           lognormal_weight
# 196           lognormal_weight
# 197           lognormal_weight
# 198           lognormal_weight
# 199           lognormal_weight
# 200           lognormal_weight
# 201           lognormal_weight

# %% [markdown]
# ### Save scaled edge file

# %%
edges_scaled_file = edges_file.replace('.csv', '_scaled.csv')
edges_scaled_df.to_csv(os.path.join(network_dir, edges_scaled_file), sep=' ', na_rep='NULL')
